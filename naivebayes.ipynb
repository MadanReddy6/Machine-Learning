# %%
import numpy as np
import pandas as pd

# %%
features = pd.read_csv('./mushrooms.csv')
features.info()

targets = features[["class"]]

features.drop("class", axis = 1, inplace=True)

total = len(features)
total
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
#  13  stalk-surface-below-ring  8124 non-null   object
#  14  stalk-color-above-ring    8124 non-null   object
#  15  stalk-color-below-ring    8124 non-null   object
#  16  veil-type                 8124 non-null   object
#  17  veil-color                8124 non-null   object
#  18  ring-number               8124 non-null   object
#  19  ring-type                 8124 non-null   object
#  20  spore-print-color         8124 non-null   object
#  21  population                8124 non-null   object
#  22  habitat                   8124 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB
# 8124

# %%
def predict(feature):
    
    P_total = {}
    
    # iterating over prediction labels (p, e)
    for target in targets["class"].unique():
        
        P_label_total = 1
        P_label = sum(targets["class"].str.count(target)) / total
        
        # iterating over columns (features)
        for i,column in enumerate(features):
            category = feature[i]
            
            P_category = sum(features[column].str.count(category)) / total
            
            filtered = targets[features[column] == category]["class"]
            P_label_category = len(filtered[filtered == target]) / len(filtered)
            
            P_category_label = P_label_category * P_category / P_label
            
            P_label_total = P_category_label * P_label_total
            P_total[target] = P_label_total
            
            # print(f"P ({column}({category}) | label({target})) = {P_category_label}")
    
    t = 0
    for key in P_total:
        t += P_total[key]
        
    for key in P_total:
        P_total[key] = P_total[key] / t
        
    return P_total

# %%
correct = 0
for i in range(len(features)):
    row = features.iloc[i]
    
    out = predict(list(row))
    
    # write code here to calculate the accuracy 
    if i < 0.5:
        correct.append(int(1))
    else:
        correct.append(int(0))
    
    
    print(i+1 , targets.iloc[i].item(),  out)
    correct
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 9
#       7 # write code here to calculate the accuracy
#       8 if i < 0.5:
# ----> 9     correct.append(int(1))
#      10 else:
#      11     correct.append(int(0))
#
# AttributeError: 'int' object has no attribute 'append'

# %%
correct = 0

for i in range(len(features)):
    row = features.iloc[i]
    
    out = predict(list(row))
    
    # Check if the prediction is correct
    if out == targets.iloc[i].item():
        correct += 1  # Increment the correct count
    
    print(i + 1, targets.iloc[i].item(), out)

# Calculate the accuracy
accuracy = correct / len(features)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# 1 p {'p': 1.0, 'e': 0.0}
# 2 e {'p': 0.0, 'e': 1.0}
# 3 e {'p': 0.0, 'e': 1.0}
# 4 p {'p': 1.0, 'e': 0.0}
# 5 e {'p': 0.0, 'e': 1.0}
# 6 e {'p': 0.0, 'e': 1.0}
# 7 e {'p': 0.0, 'e': 1.0}
# 8 e {'p': 0.0, 'e': 1.0}
# 9 p {'p': 1.0, 'e': 0.0}
# 10 e {'p': 0.0, 'e': 1.0}
# 11 e {'p': 0.0, 'e': 1.0}
# 12 e {'p': 0.0, 'e': 1.0}
# 13 e {'p': 0.0, 'e': 1.0}
# 14 p {'p': 1.0, 'e': 0.0}
# 15 e {'p': 0.0, 'e': 1.0}
# 16 e {'p': 0.0, 'e': 1.0}
# 17 e {'p': 0.0, 'e': 1.0}
# 18 p {'p': 1.0, 'e': 0.0}
# 19 p {'p': 1.0, 'e': 0.0}
# 20 p {'p': 1.0, 'e': 0.0}
# 21 e {'p': 0.0, 'e': 1.0}
# 22 p {'p': 1.0, 'e': 0.0}
# 23 e {'p': 0.0, 'e': 1.0}
# 24 e {'p': 0.0, 'e': 1.0}
# 25 e {'p': 0.0, 'e': 1.0}
# 26 p {'p': 1.0, 'e': 0.0}
# 27 e {'p': 0.0, 'e': 1.0}
# 28 e {'p': 0.0, 'e': 1.0}
# 29 e {'p': 0.00038223972456738307, 'e': 0.9996177602754326}
# 30 e {'p': 0.0, 'e': 1.0}
# 31 e {'p': 0.0, 'e': 1.0}
# 32 p {'p': 1.0, 'e': 0.0}
# 33 e {'p': 0.0, 'e': 1.0}
# 34 e {'p': 0.0, 'e': 1.0}
# 35 e {'p': 0.0, 'e': 1.0}
# 36 e {'p': 0.0, 'e': 1.0}
# 37 e {'p': 0.0, 'e': 1.0}
# 38 p {'p': 1.0, 'e': 0.0}
# 39 e {'p': 0.0, 'e': 1.0}
# 40 e {'p': 0.0, 'e': 1.0}
# 41 e {'p': 0.0, 'e': 1.0}
# 42 e {'p': 0.0, 'e': 1.0}
# 43 e {'p': 0.0037424243055083754, 'e': 0.9962575756944917}
# 44 p {'p': 1.0, 'e': 0.0}
# 45 e {'p': 0.0, 'e': 1.0}
# 46 e {'p': 0.0, 'e': 1.0}
# 47 e {'p': 0.0, 'e': 1.0}
# 48 e {'p': 0.0, 'e': 1.0}
# 49 e {'p': 0.0, 'e': 1.0}
# 50 e {'p': 0.0, 'e': 1.0}
# 51 e {'p': 0.0, 'e': 1.0}
# 52 e {'p': 0.0, 'e': 1.0}
# 53 e {'p': 0.0, 'e': 1.0}
# 54 p {'p': 1.0, 'e': 0.0}
# 55 p {'p': 1.0, 'e': 0.0}
# 56 e {'p': 0.0, 'e': 1.0}
# 57 e {'p': 0.0, 'e': 1.0}
# 58 e {'p': 0.0, 'e': 1.0}
# 59 e {'p': 0.0, 'e': 1.0}
# 60 e {'p': 0.0, 'e': 1.0}
# 61 e {'p': 0.0, 'e': 1.0}
# 62 e {'p': 0.0, 'e': 1.0}
# 63 e {'p': 0.0, 'e': 1.0}
# 64 e {'p': 0.0, 'e': 1.0}
# 65 e {'p': 0.0, 'e': 1.0}
# 66 e {'p': 0.0, 'e': 1.0}
# 67 e {'p': 0.0, 'e': 1.0}
# 68 e {'p': 0.0, 'e': 1.0}
# 69 e {'p': 0.0, 'e': 1.0}
# 70 e {'p': 0.004969343492895628, 'e': 0.9950306565071043}
# 71 e {'p': 0.0, 'e': 1.0}
# 72 e {'p': 0.0, 'e': 1.0}
# 73 e {'p': 0.0, 'e': 1.0}
# 74 e {'p': 0.0, 'e': 1.0}
# 75 e {'p': 0.0, 'e': 1.0}
# 76 e {'p': 0.0, 'e': 1.0}
# 77 e {'p': 0.0, 'e': 1.0}
# 78 e {'p': 0.0, 'e': 1.0}
# 79 p {'p': 1.0, 'e': 0.0}
# 80 e {'p': 0.0, 'e': 1.0}
# 81 e {'p': 1.6215733035797251e-06, 'e': 0.9999983784266965}
# 82 p {'p': 1.0, 'e': 0.0}
# 83 e {'p': 0.00022543112389204731, 'e': 0.9997745688761079}
# 84 e {'p': 4.775337989698058e-07, 'e': 0.9999995224662009}
# 85 e {'p': 0.0, 'e': 1.0}
# 86 e {'p': 2.0516967726750416e-06, 'e': 0.9999979483032273}
# 87 e {'p': 0.0, 'e': 1.0}
# 88 e {'p': 0.0, 'e': 1.0}
# 89 e {'p': 0.0, 'e': 1.0}
# 90 e {'p': 0.0, 'e': 1.0}
# 91 e {'p': 0.00020896072830970484, 'e': 0.9997910392716903}
# 92 e {'p': 0.0, 'e': 1.0}
# 93 e {'p': 0.0, 'e': 1.0}
# 94 e {'p': 0.0, 'e': 1.0}
# 95 e {'p': 0.0, 'e': 1.0}
# 96 e {'p': 0.0, 'e': 1.0}
# 97 e {'p': 0.0, 'e': 1.0}
# 98 e {'p': 0.0, 'e': 1.0}
# 99 e {'p': 0.0, 'e': 1.0}
# 100 e {'p': 0.0, 'e': 1.0}
# 101 e {'p': 2.734793538191978e-06, 'e': 0.9999972652064619}
# 102 e {'p': 0.0, 'e': 1.0}
# 103 e {'p': 0.0, 'e': 1.0}
# 104 e {'p': 0.0, 'e': 1.0}
# 105 e {'p': 0.0, 'e': 1.0}
# 106 e {'p': 0.0, 'e': 1.0}
# 107 e {'p': 0.0, 'e': 1.0}
# 108 e {'p': 0.0, 'e': 1.0}
# 109 e {'p': 0.0, 'e': 1.0}
# 110 e {'p': 0.0, 'e': 1.0}
# 111 e {'p': 0.0, 'e': 1.0}
# 112 e {'p': 0.0, 'e': 1.0}
# 113 e {'p': 0.0, 'e': 1.0}
# 114 e {'p': 0.0, 'e': 1.0}
# 115 p {'p': 1.0, 'e': 0.0}
# 116 e {'p': 0.0, 'e': 1.0}
# 117 e {'p': 0.0, 'e': 1.0}
# 118 e {'p': 0.0, 'e': 1.0}
# 119 e {'p': 0.0, 'e': 1.0}
# 120 e {'p': 0.0, 'e': 1.0}
# 121 p {'p': 1.0, 'e': 0.0}
# 122 e {'p': 0.0, 'e': 1.0}
# 123 p {'p': 1.0, 'e': 0.0}
# 124 e {'p': 0.0, 'e': 1.0}
# 125 e {'p': 0.0, 'e': 1.0}
# 126 e {'p': 5.080239923237031e-07, 'e': 0.9999994919760077}
# 127 e {'p': 0.0, 'e': 1.0}
# 128 e {'p': 0.0, 'e': 1.0}
# 129 e {'p': 0.0, 'e': 1.0}
# 130 e {'p': 0.0, 'e': 1.0}
# 131 e {'p': 0.0, 'e': 1.0}
# 132 e {'p': 0.0, 'e': 1.0}
# 133 e {'p': 0.0, 'e': 1.0}
# 134 e {'p': 0.0, 'e': 1.0}
# 135 e {'p': 0.0, 'e': 1.0}
# 136 p {'p': 1.0, 'e': 0.0}
# 137 e {'p': 0.0, 'e': 1.0}
# 138 e {'p': 0.0, 'e': 1.0}
# 139 p {'p': 1.0, 'e': 0.0}
# 140 e {'p': 0.0, 'e': 1.0}
# 141 e {'p': 0.0, 'e': 1.0}
# 142 e {'p': 0.0, 'e': 1.0}
# 143 e {'p': 0.0, 'e': 1.0}
# 144 e {'p': 0.0, 'e': 1.0}
# 145 e {'p': 0.0, 'e': 1.0}
# 146 e {'p': 4.5937843292607155e-07, 'e': 0.9999995406215672}
# 147 e {'p': 0.0, 'e': 1.0}
# 148 e {'p': 0.0, 'e': 1.0}
# 149 e {'p': 0.0, 'e': 1.0}
# 150 e {'p': 0.0, 'e': 1.0}
# 151 e {'p': 0.0, 'e': 1.0}
# 152 e {'p': 0.0, 'e': 1.0}
# 153 e {'p': 0.0, 'e': 1.0}
# 154 e {'p': 0.0, 'e': 1.0}
# 155 e {'p': 0.0, 'e': 1.0}
# 156 e {'p': 0.0, 'e': 1.0}
# 157 e {'p': 0.0, 'e': 1.0}
# 158 e {'p': 0.0, 'e': 1.0}
# 159 e {'p': 0.0, 'e': 1.0}
# 160 e {'p': 0.0, 'e': 1.0}
# 161 e {'p': 0.0, 'e': 1.0}
# 162 e {'p': 0.0, 'e': 1.0}
# 163 e {'p': 0.00032485808789913694, 'e': 0.9996751419121009}
# 164 e {'p': 0.0, 'e': 1.0}
# 165 e {'p': 0.0, 'e': 1.0}
# 166 e {'p': 0.0, 'e': 1.0}
# 167 e {'p': 0.0, 'e': 1.0}
# 168 e {'p': 0.0, 'e': 1.0}
# 169 e {'p': 0.0, 'e': 1.0}
# 170 e {'p': 0.0, 'e': 1.0}
# 171 e {'p': 0.0034322389402193774, 'e': 0.9965677610597807}
# 172 e {'p': 0.0, 'e': 1.0}
# 173 e {'p': 0.0, 'e': 1.0}
# 174 e {'p': 0.0, 'e': 1.0}
# 175 e {'p': 0.0, 'e': 1.0}
# 176 e {'p': 0.0, 'e': 1.0}
# 177 e {'p': 0.0, 'e': 1.0}
# 178 e {'p': 0.0, 'e': 1.0}
# 179 e {'p': 0.0, 'e': 1.0}
# 180 e {'p': 0.0, 'e': 1.0}
# 181 p {'p': 1.0, 'e': 0.0}
# 182 e {'p': 0.0, 'e': 1.0}
# 183 e {'p': 0.0161224333415269, 'e': 0.983877566658473}
# 184 e {'p': 0.0, 'e': 1.0}
# 185 e {'p': 0.0, 'e': 1.0}
# 186 p {'p': 1.0, 'e': 0.0}
# 187 e {'p': 0.0, 'e': 1.0}
# 188 e {'p': 0.005842314008139151, 'e': 0.9941576859918608}
# 189 e {'p': 0.0, 'e': 1.0}
# 190 e {'p': 0.0, 'e': 1.0}
# 191 e {'p': 1.2588164917648186e-06, 'e': 0.9999987411835083}
# 192 e {'p': 0.0, 'e': 1.0}
# 193 e {'p': 0.0, 'e': 1.0}
# 194 e {'p': 0.0, 'e': 1.0}
# 195 e {'p': 0.0, 'e': 1.0}
# 196 e {'p': 0.0038149468672305877, 'e': 0.9961850531327694}
# 197 e {'p': 0.0, 'e': 1.0}
# 198 e {'p': 0.0, 'e': 1.0}
# 199 e {'p': 0.0, 'e': 1.0}
# 200 e {'p': 0.0, 'e': 1.0}
# 201 e {'p': 0.0, 'e': 1.0}
# 202 e {'p': 0.0, 'e': 1.0}
# 203 e {'p': 0.0, 'e': 1.0}
# 204 e {'p': 5.189807374622204e-06, 'e': 0.9999948101926254}
# 205 e {'p': 0.0, 'e': 1.0}
# 206 p {'p': 1.0, 'e': 0.0}
# 207 e {'p': 0.0, 'e': 1.0}
# 208 e {'p': 0.0, 'e': 1.0}
# 209 e {'p': 0.0, 'e': 1.0}
# 210 e {'p': 0.0, 'e': 1.0}
# 211 e {'p': 0.0, 'e': 1.0}
# 212 e {'p': 0.0, 'e': 1.0}
# 213 e {'p': 0.0, 'e': 1.0}
# 214 e {'p': 0.0002027430332996647, 'e': 0.9997972569667004}
# 215 e {'p': 0.0, 'e': 1.0}
# 216 e {'p': 0.0, 'e': 1.0}
# 217 e {'p': 0.0, 'e': 1.0}
# 218 e {'p': 0.0, 'e': 1.0}
# 219 e {'p': 0.0, 'e': 1.0}
# 220 e {'p': 0.0, 'e': 1.0}
# 221 e {'p': 0.0, 'e': 1.0}
# 222 p {'p': 1.0, 'e': 0.0}
# 223 e {'p': 0.0, 'e': 1.0}
# 224 e {'p': 0.0, 'e': 1.0}
# 225 e {'p': 0.0, 'e': 1.0}
# 226 e {'p': 0.0, 'e': 1.0}
# 227 e {'p': 0.0, 'e': 1.0}
# 228 e {'p': 0.0, 'e': 1.0}
# 229 p {'p': 1.0, 'e': 0.0}
# 230 e {'p': 0.0, 'e': 1.0}
# 231 e {'p': 0.00021455077318073925, 'e': 0.9997854492268193}
# 232 p {'p': 1.0, 'e': 0.0}
# 233 e {'p': 0.0, 'e': 1.0}
# 234 e {'p': 0.0014978943839802947, 'e': 0.9985021056160197}
# 235 e {'p': 0.0, 'e': 1.0}
# 236 e {'p': 0.0, 'e': 1.0}
# 237 e {'p': 0.0, 'e': 1.0}
# 238 e {'p': 0.0, 'e': 1.0}
# 239 e {'p': 0.0, 'e': 1.0}
# 240 e {'p': 0.0, 'e': 1.0}
# 241 e {'p': 0.0, 'e': 1.0}
# 242 e {'p': 0.0, 'e': 1.0}
# 243 e {'p': 0.0, 'e': 1.0}
# 244 p {'p': 1.0, 'e': 0.0}
# 245 e {'p': 0.0, 'e': 1.0}
# 246 e {'p': 0.0, 'e': 1.0}
# 247 e {'p': 0.0, 'e': 1.0}
# 248 e {'p': 0.0, 'e': 1.0}
# 249 e {'p': 0.0, 'e': 1.0}
# 250 e {'p': 6.928550744443625e-06, 'e': 0.9999930714492556}
# 251 e {'p': 0.0, 'e': 1.0}
# 252 p {'p': 1.0, 'e': 0.0}
# 253 e {'p': 0.0, 'e': 1.0}
# 254 e {'p': 0.0, 'e': 1.0}
# 255 e {'p': 0.0, 'e': 1.0}
# 256 e {'p': 0.0, 'e': 1.0}
# 257 e {'p': 0.0014155581989910933, 'e': 0.9985844418010089}
# 258 e {'p': 0.0, 'e': 1.0}
# 259 e {'p': 0.0, 'e': 1.0}
# 260 e {'p': 0.0, 'e': 1.0}
# 261 e {'p': 0.0, 'e': 1.0}
# 262 p {'p': 1.0, 'e': 0.0}
# 263 e {'p': 0.0, 'e': 1.0}
# 264 e {'p': 0.0, 'e': 1.0}
# 265 e {'p': 0.0, 'e': 1.0}
# 266 e {'p': 0.01565011709440498, 'e': 0.984349882905595}
# 267 e {'p': 0.0, 'e': 1.0}
# 268 e {'p': 0.0, 'e': 1.0}
# 269 e {'p': 0.0, 'e': 1.0}
# 270 p {'p': 1.0, 'e': 0.0}
# 271 e {'p': 0.0, 'e': 1.0}
# 272 p {'p': 1.0, 'e': 0.0}
# 273 e {'p': 0.0, 'e': 1.0}
# 274 e {'p': 0.0, 'e': 1.0}
# 275 e {'p': 0.0, 'e': 1.0}
# 276 e {'p': 0.0, 'e': 1.0}
# 277 e {'p': 0.0, 'e': 1.0}
# 278 e {'p': 0.0, 'e': 1.0}
# 279 e {'p': 1.2527054390773737e-05, 'e': 0.9999874729456093}
# 280 e {'p': 0.0, 'e': 1.0}
# 281 p {'p': 1.0, 'e': 0.0}
# 282 e {'p': 0.0, 'e': 1.0}
# 283 e {'p': 0.0, 'e': 1.0}
# 284 e {'p': 0.0, 'e': 1.0}
# 285 e {'p': 0.0, 'e': 1.0}
# 286 e {'p': 0.0, 'e': 1.0}
# 287 e {'p': 0.0, 'e': 1.0}
# 288 e {'p': 0.0, 'e': 1.0}
# 289 e {'p': 0.0, 'e': 1.0}
# 290 e {'p': 0.0014134995895049237, 'e': 0.9985865004104951}
# 291 e {'p': 0.0036314491308467394, 'e': 0.9963685508691533}
# 292 e {'p': 0.0, 'e': 1.0}
# 293 e {'p': 0.0, 'e': 1.0}
# 294 e {'p': 0.0, 'e': 1.0}
# 295 e {'p': 0.0, 'e': 1.0}
# 296 e {'p': 0.0, 'e': 1.0}
# 297 e {'p': 0.0, 'e': 1.0}
# 298 e {'p': 1.8547647936489417e-06, 'e': 0.9999981452352064}
# 299 e {'p': 0.0, 'e': 1.0}
# 300 p {'p': 1.0, 'e': 0.0}
# 301 e {'p': 0.0, 'e': 1.0}
# 302 e {'p': 0.0, 'e': 1.0}
# 303 e {'p': 0.0, 'e': 1.0}
# 304 e {'p': 0.0, 'e': 1.0}
# 305 e {'p': 0.0, 'e': 1.0}
# 306 e {'p': 0.0, 'e': 1.0}
# 307 e {'p': 0.0, 'e': 1.0}
# 308 e {'p': 0.0, 'e': 1.0}
# 309 e {'p': 0.0, 'e': 1.0}
# 310 e {'p': 2.7107534779025593e-07, 'e': 0.9999997289246522}
# 311 e {'p': 0.0, 'e': 1.0}
# 312 p {'p': 1.0, 'e': 0.0}
# 313 e {'p': 0.0, 'e': 1.0}
# 314 e {'p': 0.0, 'e': 1.0}
# 315 e {'p': 0.0, 'e': 1.0}
# 316 p {'p': 1.0, 'e': 0.0}
# 317 e {'p': 0.0, 'e': 1.0}
# 318 e {'p': 0.0, 'e': 1.0}
# 319 e {'p': 0.0, 'e': 1.0}
# 320 e {'p': 0.0, 'e': 1.0}
# 321 e {'p': 0.0, 'e': 1.0}
# 322 e {'p': 0.0, 'e': 1.0}
# 323 e {'p': 0.0, 'e': 1.0}
# 324 e {'p': 0.0, 'e': 1.0}
# 325 e {'p': 0.0, 'e': 1.0}
# 326 e {'p': 0.0, 'e': 1.0}
# 327 e {'p': 0.0, 'e': 1.0}
# 328 p {'p': 1.0, 'e': 0.0}
# 329 e {'p': 0.0, 'e': 1.0}
# 330 e {'p': 0.0, 'e': 1.0}
# 331 p {'p': 1.0, 'e': 0.0}
# 332 e {'p': 0.0, 'e': 1.0}
# 333 e {'p': 0.0, 'e': 1.0}
# 334 e {'p': 0.0, 'e': 1.0}
# 335 e {'p': 0.0, 'e': 1.0}
# 336 e {'p': 1.446209010486634e-05, 'e': 0.9999855379098951}
# 337 e {'p': 0.0, 'e': 1.0}
# 338 e {'p': 0.0, 'e': 1.0}
# 339 e {'p': 0.013331296424580379, 'e': 0.9866687035754196}
# 340 e {'p': 0.0, 'e': 1.0}
# 341 e {'p': 0.0, 'e': 1.0}
# 342 e {'p': 0.0, 'e': 1.0}
# 343 e {'p': 0.0, 'e': 1.0}
# 344 e {'p': 0.0, 'e': 1.0}
# 345 e {'p': 0.0, 'e': 1.0}
# 346 e {'p': 0.0, 'e': 1.0}
# 347 e {'p': 0.0, 'e': 1.0}
# 348 e {'p': 0.0, 'e': 1.0}
# 349 e {'p': 9.951212147696608e-07, 'e': 0.9999990048787852}
# 350 e {'p': 0.0035371479680599057, 'e': 0.9964628520319402}
# 351 e {'p': 0.0, 'e': 1.0}
# 352 e {'p': 0.0, 'e': 1.0}
# 353 e {'p': 0.0, 'e': 1.0}
# 354 e {'p': 0.0, 'e': 1.0}
# 355 e {'p': 0.0, 'e': 1.0}
# 356 e {'p': 0.0, 'e': 1.0}
# 357 e {'p': 0.0, 'e': 1.0}
# 358 p {'p': 1.0, 'e': 0.0}
# 359 e {'p': 0.0, 'e': 1.0}
# 360 e {'p': 0.0, 'e': 1.0}
# 361 e {'p': 7.441653721669883e-06, 'e': 0.9999925583462783}
# 362 e {'p': 0.0, 'e': 1.0}
# 363 e {'p': 0.0, 'e': 1.0}
# 364 e {'p': 0.0, 'e': 1.0}
# 365 e {'p': 0.0, 'e': 1.0}
# 366 e {'p': 0.006020443809196731, 'e': 0.9939795561908031}
# 367 e {'p': 0.0, 'e': 1.0}
# 368 e {'p': 0.0, 'e': 1.0}
# 369 e {'p': 0.0, 'e': 1.0}
# 370 e {'p': 5.05351287764805e-07, 'e': 0.9999994946487122}
# 371 e {'p': 0.0, 'e': 1.0}
# 372 e {'p': 0.0, 'e': 1.0}
# 373 e {'p': 0.0, 'e': 1.0}
# 374 e {'p': 0.0, 'e': 1.0}
# 375 e {'p': 0.0, 'e': 1.0}
# 376 e {'p': 0.0, 'e': 1.0}
# 377 e {'p': 0.0, 'e': 1.0}
# 378 e {'p': 0.0, 'e': 1.0}
# 379 e {'p': 0.0, 'e': 1.0}
# 380 e {'p': 0.0, 'e': 1.0}
# 381 p {'p': 1.0, 'e': 0.0}
# 382 e {'p': 8.931024613730045e-07, 'e': 0.9999991068975387}
# 383 e {'p': 0.0, 'e': 1.0}
# 384 e {'p': 0.0, 'e': 1.0}
# 385 e {'p': 0.0, 'e': 1.0}
# 386 p {'p': 1.0, 'e': 0.0}
# 387 e {'p': 0.0, 'e': 1.0}
# 388 e {'p': 0.0, 'e': 1.0}
# 389 e {'p': 0.0, 'e': 1.0}
# 390 e {'p': 0.0, 'e': 1.0}
# 391 e {'p': 0.0, 'e': 1.0}
# 392 e {'p': 0.0, 'e': 1.0}
# 393 e {'p': 0.0, 'e': 1.0}
# 394 e {'p': 0.001235397874757138, 'e': 0.9987646021252429}
# 395 e {'p': 0.0, 'e': 1.0}
# 396 e {'p': 0.0, 'e': 1.0}
# 397 e {'p': 0.0, 'e': 1.0}
# 398 e {'p': 0.0, 'e': 1.0}
# 399 e {'p': 0.0008411784749087097, 'e': 0.9991588215250913}
# 400 p {'p': 1.0, 'e': 0.0}
# 401 e {'p': 0.0, 'e': 1.0}
# 402 e {'p': 0.0, 'e': 1.0}
# 403 p {'p': 1.0, 'e': 0.0}
# 404 e {'p': 0.0, 'e': 1.0}
# 405 e {'p': 0.0, 'e': 1.0}
# 406 e {'p': 0.0, 'e': 1.0}
# 407 e {'p': 0.0, 'e': 1.0}
# 408 e {'p': 0.0, 'e': 1.0}
# 409 e {'p': 0.0, 'e': 1.0}
# 410 e {'p': 0.0, 'e': 1.0}
# 411 e {'p': 0.0, 'e': 1.0}
# 412 e {'p': 7.714934114620652e-07, 'e': 0.9999992285065886}
# 413 e {'p': 0.0, 'e': 1.0}
# 414 e {'p': 0.0, 'e': 1.0}
# 415 p {'p': 1.0, 'e': 0.0}
# 416 e {'p': 0.0, 'e': 1.0}
# 417 e {'p': 0.0, 'e': 1.0}
# 418 p {'p': 1.0, 'e': 0.0}
# 419 e {'p': 0.0, 'e': 1.0}
# 420 e {'p': 0.0, 'e': 1.0}
# 421 e {'p': 0.0, 'e': 1.0}
# 422 e {'p': 0.0, 'e': 1.0}
# 423 p {'p': 1.0, 'e': 0.0}
# 424 e {'p': 0.0, 'e': 1.0}
# 425 e {'p': 0.0, 'e': 1.0}
# 426 e {'p': 0.0, 'e': 1.0}
# 427 e {'p': 0.0, 'e': 1.0}
# 428 e {'p': 0.0, 'e': 1.0}
# 429 e {'p': 0.0, 'e': 1.0}
# 430 e {'p': 0.0008838084297946528, 'e': 0.9991161915702055}
# 431 e {'p': 0.0, 'e': 1.0}
# 432 e {'p': 0.0, 'e': 1.0}
# 433 e {'p': 0.0, 'e': 1.0}
# 434 e {'p': 0.0, 'e': 1.0}
# 435 e {'p': 0.0, 'e': 1.0}
# 436 e {'p': 0.0, 'e': 1.0}
# 437 e {'p': 0.0, 'e': 1.0}
# 438 e {'p': 0.0, 'e': 1.0}
# 439 e {'p': 0.0, 'e': 1.0}
# 440 e {'p': 0.0, 'e': 1.0}
# 441 e {'p': 0.0, 'e': 1.0}
# 442 e {'p': 0.0, 'e': 1.0}
# 443 e {'p': 0.0, 'e': 1.0}
# 444 e {'p': 0.0, 'e': 1.0}
# 445 e {'p': 0.0, 'e': 1.0}
# 446 e {'p': 0.0, 'e': 1.0}
# 447 e {'p': 0.0, 'e': 1.0}
# 448 e {'p': 0.0, 'e': 1.0}
# 449 e {'p': 0.0, 'e': 1.0}
# 450 e {'p': 0.0, 'e': 1.0}
# 451 e {'p': 0.0, 'e': 1.0}
# 452 e {'p': 0.0, 'e': 1.0}
# 453 e {'p': 0.0, 'e': 1.0}
# 454 e {'p': 0.0, 'e': 1.0}
# 455 e {'p': 0.0, 'e': 1.0}
# 456 e {'p': 0.0, 'e': 1.0}
# 457 e {'p': 0.0, 'e': 1.0}
# 458 e {'p': 0.0, 'e': 1.0}
# 459 e {'p': 0.0, 'e': 1.0}
# 460 e {'p': 0.0, 'e': 1.0}
# 461 e {'p': 0.0, 'e': 1.0}
# 462 e {'p': 0.0, 'e': 1.0}
# 463 e {'p': 0.0, 'e': 1.0}
# 464 e {'p': 0.0, 'e': 1.0}
# 465 e {'p': 0.001347314209047779, 'e': 0.9986526857909522}
# 466 e {'p': 0.0, 'e': 1.0}
# 467 e {'p': 0.0, 'e': 1.0}
# 468 e {'p': 0.0, 'e': 1.0}
# 469 e {'p': 0.0, 'e': 1.0}
# 470 e {'p': 0.0, 'e': 1.0}
# 471 e {'p': 0.0, 'e': 1.0}
# 472 e {'p': 0.0, 'e': 1.0}
# 473 e {'p': 0.0, 'e': 1.0}
# 474 e {'p': 0.0, 'e': 1.0}
# 475 e {'p': 0.0, 'e': 1.0}
# 476 e {'p': 0.0003708679687731558, 'e': 0.9996291320312268}
# 477 e {'p': 0.0013103405823427993, 'e': 0.9986896594176572}
# 478 e {'p': 0.0, 'e': 1.0}
# 479 e {'p': 0.0, 'e': 1.0}
# 480 e {'p': 0.0, 'e': 1.0}
# 481 e {'p': 0.0, 'e': 1.0}
# 482 e {'p': 0.0, 'e': 1.0}
# 483 e {'p': 0.0, 'e': 1.0}
# 484 e {'p': 0.004036279799711369, 'e': 0.9959637202002886}
# 485 e {'p': 0.0, 'e': 1.0}
# 486 e {'p': 0.0, 'e': 1.0}
# 487 e {'p': 0.0, 'e': 1.0}
# 488 e {'p': 0.0, 'e': 1.0}
# 489 e {'p': 0.0, 'e': 1.0}
# 490 e {'p': 0.0, 'e': 1.0}
# 491 e {'p': 0.0, 'e': 1.0}
# 492 p {'p': 1.0, 'e': 0.0}
# 493 p {'p': 1.0, 'e': 0.0}
# 494 e {'p': 0.0, 'e': 1.0}
# 495 e {'p': 0.0, 'e': 1.0}
# 496 e {'p': 0.0, 'e': 1.0}
# 497 e {'p': 0.0, 'e': 1.0}
# 498 e {'p': 0.0, 'e': 1.0}
# 499 e {'p': 0.0, 'e': 1.0}
# 500 e {'p': 0.0, 'e': 1.0}
# 501 e {'p': 0.0, 'e': 1.0}
# 502 e {'p': 0.0, 'e': 1.0}
# 503 e {'p': 0.0, 'e': 1.0}
# 504 e {'p': 0.0, 'e': 1.0}
# 505 e {'p': 0.0, 'e': 1.0}
# 506 p {'p': 1.0, 'e': 0.0}
# 507 e {'p': 7.5948448813988595e-06, 'e': 0.9999924051551186}
# 508 e {'p': 0.0, 'e': 1.0}
# 509 e {'p': 0.0, 'e': 1.0}
# 510 e {'p': 0.005522494749806906, 'e': 0.9944775052501931}
# 511 e {'p': 0.00036120660583047345, 'e': 0.9996387933941695}
# 512 e {'p': 0.0, 'e': 1.0}
# 513 e {'p': 0.0, 'e': 1.0}
# 514 e {'p': 0.0, 'e': 1.0}
# 515 e {'p': 0.0012732445531632081, 'e': 0.9987267554468368}
# 516 e {'p': 0.0, 'e': 1.0}
# 517 e {'p': 0.0, 'e': 1.0}
# 518 e {'p': 0.0, 'e': 1.0}
# 519 e {'p': 0.0, 'e': 1.0}
# 520 e {'p': 0.0, 'e': 1.0}
# 521 e {'p': 0.0, 'e': 1.0}
# 522 e {'p': 0.0, 'e': 1.0}
# 523 e {'p': 0.0, 'e': 1.0}
# 524 p {'p': 1.0, 'e': 0.0}
# 525 e {'p': 0.00023855990127449704, 'e': 0.9997614400987255}
# 526 e {'p': 0.0, 'e': 1.0}
# 527 e {'p': 0.0, 'e': 1.0}
# 528 e {'p': 0.0, 'e': 1.0}
# 529 e {'p': 0.0003437753544833008, 'e': 0.9996562246455167}
# 530 e {'p': 0.0, 'e': 1.0}
# 531 e {'p': 0.0, 'e': 1.0}
# 532 e {'p': 0.0, 'e': 1.0}
# 533 p {'p': 1.0, 'e': 0.0}
# 534 e {'p': 0.0, 'e': 1.0}
# 535 p {'p': 1.0, 'e': 0.0}
# 536 e {'p': 3.730534897979072e-07, 'e': 0.9999996269465102}
# 537 e {'p': 0.0, 'e': 1.0}
# 538 e {'p': 0.0, 'e': 1.0}
# 539 e {'p': 0.0, 'e': 1.0}
# 540 e {'p': 0.0, 'e': 1.0}
# 541 e {'p': 0.0, 'e': 1.0}
# 542 e {'p': 2.4657774310422675e-06, 'e': 0.9999975342225689}
# 543 p {'p': 1.0, 'e': 0.0}
# 544 e {'p': 0.0, 'e': 1.0}
# 545 e {'p': 0.0, 'e': 1.0}
# 546 e {'p': 0.0, 'e': 1.0}
# 547 e {'p': 0.0, 'e': 1.0}
# 548 e {'p': 0.014801393779803655, 'e': 0.9851986062201963}
# 549 e {'p': 0.0, 'e': 1.0}
# 550 e {'p': 0.0, 'e': 1.0}
# 551 e {'p': 0.0002323444523965708, 'e': 0.9997676555476035}
# 552 e {'p': 8.639222298615284e-06, 'e': 0.9999913607777013}
# 553 e {'p': 0.0, 'e': 1.0}
# 554 e {'p': 0.0, 'e': 1.0}
# 555 e {'p': 0.0, 'e': 1.0}
# 556 e {'p': 0.0, 'e': 1.0}
# 557 p {'p': 1.0, 'e': 0.0}
# 558 e {'p': 0.0, 'e': 1.0}
# 559 e {'p': 0.0, 'e': 1.0}
# 560 e {'p': 0.0, 'e': 1.0}
# 561 e {'p': 0.0, 'e': 1.0}
# 562 e {'p': 0.0, 'e': 1.0}
# 563 e {'p': 0.0, 'e': 1.0}
# 564 e {'p': 2.3993400721590307e-07, 'e': 0.9999997600659928}
# 565 e {'p': 0.0, 'e': 1.0}
# 566 p {'p': 1.0, 'e': 0.0}
# 567 e {'p': 0.0, 'e': 1.0}
# 568 e {'p': 1.5472308019444348e-06, 'e': 0.9999984527691982}
# 569 p {'p': 1.0, 'e': 0.0}
# 570 e {'p': 0.0, 'e': 1.0}
# 571 e {'p': 0.0, 'e': 1.0}
# 572 e {'p': 0.0, 'e': 1.0}
# 573 e {'p': 0.0, 'e': 1.0}
# 574 e {'p': 0.0, 'e': 1.0}
# 575 e {'p': 0.0, 'e': 1.0}
# 576 e {'p': 0.0, 'e': 1.0}
# 577 e {'p': 0.005120993878578888, 'e': 0.9948790061214211}
# 578 e {'p': 0.0, 'e': 1.0}
# 579 e {'p': 0.0, 'e': 1.0}
# 580 p {'p': 1.0, 'e': 0.0}
# 581 e {'p': 0.0, 'e': 1.0}
# 582 e {'p': 0.0, 'e': 1.0}
# 583 e {'p': 0.0, 'e': 1.0}
# 584 e {'p': 0.0, 'e': 1.0}
# 585 e {'p': 0.0, 'e': 1.0}
# 586 e {'p': 0.0, 'e': 1.0}
# 587 e {'p': 0.0, 'e': 1.0}
# 588 e {'p': 0.000245875752854595, 'e': 0.9997541242471455}
# 589 e {'p': 0.0, 'e': 1.0}
# 590 e {'p': 0.0, 'e': 1.0}
# 591 p {'p': 1.0, 'e': 0.0}
# 592 e {'p': 1.9357612838107722e-05, 'e': 0.9999806423871619}
# 593 e {'p': 0.0, 'e': 1.0}
# 594 p {'p': 1.0, 'e': 0.0}
# 595 e {'p': 0.0, 'e': 1.0}
# 596 p {'p': 1.0, 'e': 0.0}
# 597 e {'p': 0.0, 'e': 1.0}
# 598 e {'p': 0.0, 'e': 1.0}
# 599 p {'p': 1.0, 'e': 0.0}
# 600 p {'p': 1.0, 'e': 0.0}
# 601 e {'p': 0.0, 'e': 1.0}
# 602 e {'p': 0.0, 'e': 1.0}
# 603 e {'p': 0.0, 'e': 1.0}
# 604 e {'p': 0.0, 'e': 1.0}
# 605 e {'p': 0.0, 'e': 1.0}
# 606 e {'p': 0.0, 'e': 1.0}
# 607 e {'p': 8.456856956917102e-07, 'e': 0.9999991543143043}
# 608 e {'p': 0.0, 'e': 1.0}
# 609 e {'p': 0.0, 'e': 1.0}
# 610 e {'p': 0.0009352442658934027, 'e': 0.9990647557341066}
# 611 e {'p': 0.0, 'e': 1.0}
# 612 e {'p': 3.338024567972454e-07, 'e': 0.9999996661975432}
# 613 e {'p': 0.0, 'e': 1.0}
# 614 p {'p': 1.0, 'e': 0.0}
# 615 e {'p': 0.0, 'e': 1.0}
# 616 e {'p': 0.0, 'e': 1.0}
# 617 e {'p': 0.0, 'e': 1.0}
# 618 e {'p': 0.0, 'e': 1.0}
# 619 e {'p': 0.0, 'e': 1.0}
# 620 e {'p': 0.0, 'e': 1.0}
# 621 e {'p': 0.0, 'e': 1.0}
# 622 e {'p': 0.0, 'e': 1.0}
# 623 e {'p': 0.0, 'e': 1.0}
# 624 e {'p': 0.0, 'e': 1.0}
# 625 e {'p': 0.0014957162144709287, 'e': 0.9985042837855291}
# 626 e {'p': 0.0, 'e': 1.0}
# 627 e {'p': 0.0, 'e': 1.0}
# 628 e {'p': 0.0, 'e': 1.0}
# 629 e {'p': 0.0, 'e': 1.0}
# 630 e {'p': 0.0, 'e': 1.0}
# 631 e {'p': 5.472721039460011e-07, 'e': 0.999999452727896}
# 632 e {'p': 0.0, 'e': 1.0}
# 633 e {'p': 0.0, 'e': 1.0}
# 634 e {'p': 0.0, 'e': 1.0}
# 635 e {'p': 0.0, 'e': 1.0}
# 636 e {'p': 0.0, 'e': 1.0}
# 637 e {'p': 0.0, 'e': 1.0}
# 638 e {'p': 0.0, 'e': 1.0}
# 639 e {'p': 2.8541966643293618e-05, 'e': 0.9999714580333566}
# 640 e {'p': 0.0, 'e': 1.0}
# 641 e {'p': 0.0, 'e': 1.0}
# 642 e {'p': 0.0, 'e': 1.0}
# 643 e {'p': 0.0, 'e': 1.0}
# 644 e {'p': 0.0, 'e': 1.0}
# 645 e {'p': 0.0, 'e': 1.0}
# 646 e {'p': 0.0, 'e': 1.0}
# 647 e {'p': 0.0, 'e': 1.0}
# 648 e {'p': 0.0, 'e': 1.0}
# 649 e {'p': 0.0, 'e': 1.0}
# 650 e {'p': 0.0, 'e': 1.0}
# 651 e {'p': 0.0, 'e': 1.0}
# 652 e {'p': 0.0, 'e': 1.0}
# 653 e {'p': 0.0, 'e': 1.0}
# 654 p {'p': 1.0, 'e': 0.0}
# 655 p {'p': 1.0, 'e': 0.0}
# 656 e {'p': 0.0, 'e': 1.0}
# 657 e {'p': 4.686483444250866e-07, 'e': 0.9999995313516554}
# 658 e {'p': 0.0, 'e': 1.0}
# 659 e {'p': 0.0, 'e': 1.0}
# 660 e {'p': 0.00035046037275958294, 'e': 0.9996495396272405}
# 661 e {'p': 0.0, 'e': 1.0}
# 662 e {'p': 0.0, 'e': 1.0}
# 663 p {'p': 1.0, 'e': 0.0}
# 664 p {'p': 1.0, 'e': 0.0}
# 665 e {'p': 0.0, 'e': 1.0}
# 666 e {'p': 0.0, 'e': 1.0}
# 667 e {'p': 0.0, 'e': 1.0}
# 668 e {'p': 0.0, 'e': 1.0}
# 669 e {'p': 0.0, 'e': 1.0}
# 670 e {'p': 0.0, 'e': 1.0}
# 671 e {'p': 0.0, 'e': 1.0}
# 672 e {'p': 0.005690929209765505, 'e': 0.9943090707902345}
# 673 e {'p': 0.0, 'e': 1.0}
# 674 e {'p': 0.0, 'e': 1.0}
# 675 e {'p': 0.0, 'e': 1.0}
# 676 e {'p': 0.004159574739233223, 'e': 0.9958404252607668}
# 677 e {'p': 0.0013734871226839137, 'e': 0.9986265128773161}
# 678 e {'p': 0.0, 'e': 1.0}
# 679 e {'p': 0.0, 'e': 1.0}
# 680 e {'p': 0.0, 'e': 1.0}
# 681 e {'p': 0.0, 'e': 1.0}
# 682 e {'p': 0.0, 'e': 1.0}
# 683 e {'p': 0.0, 'e': 1.0}
# 684 e {'p': 0.0, 'e': 1.0}
# 685 e {'p': 5.361115189896223e-05, 'e': 0.999946388848101}
# 686 e {'p': 0.0, 'e': 1.0}
# 687 e {'p': 0.0014533797978827773, 'e': 0.9985466202021172}
# 688 e {'p': 0.0, 'e': 1.0}
# 689 e {'p': 0.0, 'e': 1.0}
# 690 e {'p': 0.0, 'e': 1.0}
# 691 e {'p': 0.0, 'e': 1.0}
# 692 e {'p': 0.0, 'e': 1.0}
# 693 e {'p': 0.0, 'e': 1.0}
# 694 e {'p': 0.0, 'e': 1.0}
# 695 p {'p': 1.0, 'e': 0.0}
# 696 e {'p': 0.0, 'e': 1.0}
# 697 e {'p': 0.0, 'e': 1.0}
# 698 p {'p': 1.0, 'e': 0.0}
# 699 p {'p': 1.0, 'e': 0.0}
# 700 e {'p': 0.0, 'e': 1.0}
# 701 p {'p': 1.0, 'e': 0.0}
# 702 e {'p': 0.0, 'e': 1.0}
# 703 e {'p': 0.0, 'e': 1.0}
# 704 e {'p': 0.0, 'e': 1.0}
# 705 e {'p': 0.0, 'e': 1.0}
# 706 e {'p': 0.0, 'e': 1.0}
# 707 e {'p': 0.0, 'e': 1.0}
# 708 e {'p': 0.0, 'e': 1.0}
# 709 e {'p': 0.0, 'e': 1.0}
# 710 e {'p': 0.0, 'e': 1.0}
# 711 e {'p': 0.0, 'e': 1.0}
# 712 e {'p': 0.0, 'e': 1.0}
# 713 e {'p': 0.0, 'e': 1.0}
# 714 e {'p': 0.0, 'e': 1.0}
# 715 e {'p': 0.0, 'e': 1.0}
# 716 e {'p': 0.0, 'e': 1.0}
# 717 e {'p': 0.0, 'e': 1.0}
# 718 e {'p': 0.0, 'e': 1.0}
# 719 e {'p': 0.0, 'e': 1.0}
# 720 e {'p': 0.0, 'e': 1.0}
# 721 e {'p': 0.0, 'e': 1.0}
# 722 e {'p': 0.0, 'e': 1.0}
# 723 e {'p': 0.0, 'e': 1.0}
# 724 e {'p': 0.0, 'e': 1.0}
# 725 e {'p': 0.0, 'e': 1.0}
# 726 p {'p': 1.0, 'e': 0.0}
# 727 e {'p': 0.0, 'e': 1.0}
# 728 e {'p': 4.904131305459337e-06, 'e': 0.9999950958686945}
# 729 e {'p': 0.0, 'e': 1.0}
# 730 e {'p': 0.0, 'e': 1.0}
# 731 e {'p': 0.0, 'e': 1.0}
# 732 e {'p': 4.1165943673798025e-07, 'e': 0.9999995883405632}
# 733 p {'p': 1.0, 'e': 0.0}
# 734 p {'p': 1.0, 'e': 0.0}
# 735 e {'p': 0.0, 'e': 1.0}
# 736 e {'p': 0.0, 'e': 1.0}
# 737 e {'p': 0.0, 'e': 1.0}
# 738 p {'p': 1.0, 'e': 0.0}
# 739 e {'p': 0.0, 'e': 1.0}
# 740 e {'p': 0.0052572979496066695, 'e': 0.9947427020503933}
# 741 e {'p': 0.005417688049330862, 'e': 0.9945823119506692}
# 742 e {'p': 0.0, 'e': 1.0}
# 743 e {'p': 0.0, 'e': 1.0}
# 744 e {'p': 0.0, 'e': 1.0}
# 745 e {'p': 0.0, 'e': 1.0}
# 746 e {'p': 0.0, 'e': 1.0}
# 747 e {'p': 0.0, 'e': 1.0}
# 748 e {'p': 0.0, 'e': 1.0}
# 749 p {'p': 1.0, 'e': 0.0}
# 750 e {'p': 0.0, 'e': 1.0}
# 751 e {'p': 0.0, 'e': 1.0}
# 752 e {'p': 0.0, 'e': 1.0}
# 753 e {'p': 0.0, 'e': 1.0}
# 754 e {'p': 0.0, 'e': 1.0}
# 755 e {'p': 0.0, 'e': 1.0}
# 756 e {'p': 0.0, 'e': 1.0}
# 757 e {'p': 0.0, 'e': 1.0}
# 758 e {'p': 0.0, 'e': 1.0}
# 759 e {'p': 0.0, 'e': 1.0}
# 760 e {'p': 0.0, 'e': 1.0}
# 761 e {'p': 0.0, 'e': 1.0}
# 762 e {'p': 0.0, 'e': 1.0}
# 763 e {'p': 0.0, 'e': 1.0}
# 764 e {'p': 0.013734607747276834, 'e': 0.9862653922527231}
# 765 e {'p': 0.0, 'e': 1.0}
# 766 e {'p': 0.0, 'e': 1.0}
# 767 e {'p': 0.0, 'e': 1.0}
# 768 e {'p': 0.003931507509513431, 'e': 0.9960684924904866}
# 769 e {'p': 0.0, 'e': 1.0}
# 770 e {'p': 0.0, 'e': 1.0}
# 771 e {'p': 0.0, 'e': 1.0}
# 772 e {'p': 0.0, 'e': 1.0}
# 773 e {'p': 0.0, 'e': 1.0}
# 774 e {'p': 0.0, 'e': 1.0}
# 775 e {'p': 0.0, 'e': 1.0}
# 776 e {'p': 0.0, 'e': 1.0}
# 777 p {'p': 1.0, 'e': 0.0}
# 778 e {'p': 0.0, 'e': 1.0}
# 779 e {'p': 0.0, 'e': 1.0}
# 780 e {'p': 0.0, 'e': 1.0}
# 781 e {'p': 0.0, 'e': 1.0}
# 782 e {'p': 0.0, 'e': 1.0}
# 783 e {'p': 0.0, 'e': 1.0}
# 784 e {'p': 0.0, 'e': 1.0}
# 785 e {'p': 0.0, 'e': 1.0}
# 786 p {'p': 1.0, 'e': 0.0}
# 787 e {'p': 0.0008669586408002446, 'e': 0.9991330413591997}
# 788 e {'p': 0.0, 'e': 1.0}
# 789 p {'p': 1.0, 'e': 0.0}
# 790 e {'p': 0.0, 'e': 1.0}
# 791 e {'p': 0.0, 'e': 1.0}
# 792 e {'p': 0.0, 'e': 1.0}
# 793 e {'p': 0.0, 'e': 1.0}
# 794 e {'p': 0.0, 'e': 1.0}
# 795 p {'p': 1.0, 'e': 0.0}
# 796 p {'p': 1.0, 'e': 0.0}
# 797 e {'p': 0.0, 'e': 1.0}
# 798 e {'p': 1.3148235095529492e-05, 'e': 0.9999868517649045}
# 799 p {'p': 1.0, 'e': 0.0}
# 800 e {'p': 0.0, 'e': 1.0}
# 801 e {'p': 0.0, 'e': 1.0}
# 802 e {'p': 0.0, 'e': 1.0}
# 803 p {'p': 1.0, 'e': 0.0}
# 804 e {'p': 0.0, 'e': 1.0}
# 805 e {'p': 0.0, 'e': 1.0}
# 806 e {'p': 0.0, 'e': 1.0}
# 807 e {'p': 0.0, 'e': 1.0}
# 808 e {'p': 0.0, 'e': 1.0}
# 809 e {'p': 0.0, 'e': 1.0}
# 810 e {'p': 0.0, 'e': 1.0}
# 811 e {'p': 0.0, 'e': 1.0}
# 812 e {'p': 0.0, 'e': 1.0}
# 813 p {'p': 1.0, 'e': 0.0}
# 814 p {'p': 1.0, 'e': 0.0}
# 815 p {'p': 1.0, 'e': 0.0}
# 816 e {'p': 0.0, 'e': 1.0}
# 817 e {'p': 0.0, 'e': 1.0}
# 818 e {'p': 0.0, 'e': 1.0}
# 819 e {'p': 0.0, 'e': 1.0}
# 820 e {'p': 0.0, 'e': 1.0}
# 821 e {'p': 0.0, 'e': 1.0}
# 822 e {'p': 0.001307268722005074, 'e': 0.9986927312779948}
# 823 e {'p': 0.0, 'e': 1.0}
# 824 e {'p': 0.0, 'e': 1.0}
# 825 e {'p': 0.0, 'e': 1.0}
# 826 e {'p': 0.0, 'e': 1.0}
# 827 e {'p': 0.0, 'e': 1.0}
# 828 e {'p': 0.0, 'e': 1.0}
# 829 e {'p': 0.0, 'e': 1.0}
# 830 e {'p': 0.0, 'e': 1.0}
# 831 e {'p': 0.0, 'e': 1.0}
# 832 e {'p': 0.0, 'e': 1.0}
# 833 e {'p': 0.0, 'e': 1.0}
# 834 e {'p': 0.0, 'e': 1.0}
# 835 e {'p': 0.0, 'e': 1.0}
# 836 p {'p': 1.0, 'e': 0.0}
# 837 e {'p': 0.0, 'e': 1.0}
# 838 p {'p': 1.0, 'e': 0.0}
# 839 e {'p': 0.0, 'e': 1.0}
# 840 e {'p': 0.0, 'e': 1.0}
# 841 e {'p': 0.0, 'e': 1.0}
# 842 p {'p': 1.0, 'e': 0.0}
# 843 e {'p': 0.0, 'e': 1.0}
# 844 e {'p': 0.0, 'e': 1.0}
# 845 e {'p': 0.0, 'e': 1.0}
# 846 e {'p': 5.190017303965252e-07, 'e': 0.9999994809982696}
# 847 e {'p': 0.0, 'e': 1.0}
# 848 e {'p': 0.0, 'e': 1.0}
# 849 e {'p': 0.0, 'e': 1.0}
# 850 e {'p': 0.0, 'e': 1.0}
# 851 e {'p': 0.0, 'e': 1.0}
# 852 e {'p': 0.0, 'e': 1.0}
# 853 e {'p': 0.0, 'e': 1.0}
# 854 e {'p': 0.0, 'e': 1.0}
# 855 e {'p': 0.0, 'e': 1.0}
# 856 e {'p': 0.0, 'e': 1.0}
# 857 e {'p': 0.0, 'e': 1.0}
# 858 e {'p': 0.0, 'e': 1.0}
# 859 e {'p': 0.0, 'e': 1.0}
# 860 p {'p': 1.0, 'e': 0.0}
# 861 e {'p': 0.0, 'e': 1.0}
# 862 e {'p': 0.0, 'e': 1.0}
# 863 e {'p': 0.0, 'e': 1.0}
# 864 e {'p': 0.0, 'e': 1.0}
# 865 e {'p': 0.0, 'e': 1.0}
# 866 e {'p': 0.0, 'e': 1.0}
# 867 e {'p': 0.0009108939136654238, 'e': 0.9990891060863345}
# 868 e {'p': 0.0, 'e': 1.0}
# 869 e {'p': 0.0012713926432079148, 'e': 0.9987286073567921}
# 870 e {'p': 0.0, 'e': 1.0}
# 871 e {'p': 0.0, 'e': 1.0}
# 872 e {'p': 0.0, 'e': 1.0}
# 873 e {'p': 0.0, 'e': 1.0}
# 874 e {'p': 0.0, 'e': 1.0}
# 875 e {'p': 0.0, 'e': 1.0}
# 876 e {'p': 0.0, 'e': 1.0}
# 877 e {'p': 0.0, 'e': 1.0}
# 878 e {'p': 0.0, 'e': 1.0}
# 879 e {'p': 0.0, 'e': 1.0}
# 880 e {'p': 0.0, 'e': 1.0}
# 881 e {'p': 0.0, 'e': 1.0}
# 882 e {'p': 9.403439517047005e-07, 'e': 0.9999990596560483}
# 883 e {'p': 0.0, 'e': 1.0}
# 884 e {'p': 0.0, 'e': 1.0}
# 885 e {'p': 0.0, 'e': 1.0}
# 886 e {'p': 0.0, 'e': 1.0}
# 887 e {'p': 0.0, 'e': 1.0}
# 888 e {'p': 0.0, 'e': 1.0}
# 889 e {'p': 0.0, 'e': 1.0}
# 890 e {'p': 0.0, 'e': 1.0}
# 891 e {'p': 0.0, 'e': 1.0}
# 892 e {'p': 0.0, 'e': 1.0}
# 893 e {'p': 0.0, 'e': 1.0}
# 894 e {'p': 0.0, 'e': 1.0}
# 895 e {'p': 0.0, 'e': 1.0}
# 896 e {'p': 0.0, 'e': 1.0}
# 897 e {'p': 0.0, 'e': 1.0}
# 898 e {'p': 0.0, 'e': 1.0}
# 899 e {'p': 0.0, 'e': 1.0}
# 900 e {'p': 0.0, 'e': 1.0}
# 901 e {'p': 0.0, 'e': 1.0}
# 902 e {'p': 0.0, 'e': 1.0}
# 903 e {'p': 4.843158235442285e-06, 'e': 0.9999951568417647}
# 904 e {'p': 1.242448802752362e-05, 'e': 0.9999875755119725}
# 905 e {'p': 0.0, 'e': 1.0}
# 906 e {'p': 1.6748163090437747e-06, 'e': 0.999998325183691}
# 907 p {'p': 1.0, 'e': 0.0}
# 908 e {'p': 1.7526678279867934e-06, 'e': 0.999998247332172}
# 909 p {'p': 1.0, 'e': 0.0}
# 910 p {'p': 1.0, 'e': 0.0}
# 911 e {'p': 0.0, 'e': 1.0}
# 912 e {'p': 0.0, 'e': 1.0}
# 913 e {'p': 0.0, 'e': 1.0}
# 914 e {'p': 0.0, 'e': 1.0}
# 915 e {'p': 1.9906356040464954e-06, 'e': 0.9999980093643959}
# 916 e {'p': 0.0, 'e': 1.0}
# 917 e {'p': 0.0, 'e': 1.0}
# 918 e {'p': 0.0, 'e': 1.0}
# 919 e {'p': 0.0, 'e': 1.0}
# 920 e {'p': 1.0988571859718181e-05, 'e': 0.9999890114281402}
# 921 e {'p': 0.0, 'e': 1.0}
# 922 e {'p': 0.0, 'e': 1.0}
# 923 e {'p': 0.0, 'e': 1.0}
# 924 e {'p': 0.0, 'e': 1.0}
# 925 e {'p': 3.9197612695334953e-07, 'e': 0.9999996080238731}
# 926 e {'p': 0.0, 'e': 1.0}
# 927 e {'p': 0.0, 'e': 1.0}
# 928 p {'p': 1.0, 'e': 0.0}
# 929 e {'p': 0.0003151929161302501, 'e': 0.9996848070838698}
# 930 e {'p': 0.0, 'e': 1.0}
# 931 e {'p': 0.0, 'e': 1.0}
# 932 e {'p': 3.7116524602106144e-07, 'e': 0.999999628834754}
# 933 p {'p': 1.0, 'e': 0.0}
# 934 e {'p': 0.0, 'e': 1.0}
# 935 e {'p': 0.00022113050621561214, 'e': 0.9997788694937845}
# 936 e {'p': 3.546164686997789e-06, 'e': 0.999996453835313}
# 937 e {'p': 0.0, 'e': 1.0}
# 938 e {'p': 3.269729426231492e-06, 'e': 0.9999967302705738}
# 939 e {'p': 0.0, 'e': 1.0}
# 940 e {'p': 0.0, 'e': 1.0}
# 941 e {'p': 0.0, 'e': 1.0}
# 942 e {'p': 1.6771704018234486e-07, 'e': 0.9999998322829599}
# 943 p {'p': 1.0, 'e': 0.0}
# 944 e {'p': 2.997790136499681e-06, 'e': 0.9999970022098634}
# 945 e {'p': 0.0, 'e': 1.0}
# 946 e {'p': 0.0, 'e': 1.0}
# 947 e {'p': 1.8648975275895745e-07, 'e': 0.9999998135102472}
# 948 e {'p': 0.0, 'e': 1.0}
# 949 e {'p': 0.0, 'e': 1.0}
# 950 p {'p': 1.0, 'e': 0.0}
# 951 p {'p': 1.0, 'e': 0.0}
# 952 e {'p': 0.0, 'e': 1.0}
# 953 e {'p': 0.0, 'e': 1.0}
# 954 e {'p': 0.0, 'e': 1.0}
# 955 e {'p': 9.900869296828308e-06, 'e': 0.9999900991307032}
# 956 e {'p': 0.0, 'e': 1.0}
# 957 p {'p': 1.0, 'e': 0.0}
# 958 e {'p': 7.771915636111434e-05, 'e': 0.9999222808436389}
# 959 e {'p': 0.0, 'e': 1.0}
# 960 e {'p': 0.0, 'e': 1.0}
# 961 e {'p': 0.0, 'e': 1.0}
# 962 e {'p': 0.0, 'e': 1.0}
# 963 e {'p': 0.0, 'e': 1.0}
# 964 e {'p': 0.0, 'e': 1.0}
# 965 e {'p': 1.294099619644887e-06, 'e': 0.9999987059003804}
# 966 e {'p': 1.423608092542813e-06, 'e': 0.9999985763919075}
# 967 p {'p': 1.0, 'e': 0.0}
# 968 e {'p': 2.3066987120923912e-06, 'e': 0.999997693301288}
# 969 e {'p': 1.199530770822e-06, 'e': 0.9999988004692292}
# 970 e {'p': 3.117769379929825e-07, 'e': 0.9999996882230621}
# 971 e {'p': 4.5773681910021556e-07, 'e': 0.9999995422631809}
# 972 e {'p': 9.03785907377743e-06, 'e': 0.9999909621409262}
# 973 e {'p': 1.0049464436668955e-05, 'e': 0.9999899505355633}
# 974 e {'p': 3.532472532369995e-07, 'e': 0.9999996467527468}
# 975 e {'p': 2.3143658833808877e-06, 'e': 0.9999976856341166}
# 976 e {'p': 4.699019927726189e-06, 'e': 0.9999953009800723}
# 977 e {'p': 0.0, 'e': 1.0}
# 978 e {'p': 8.342869281530126e-06, 'e': 0.9999916571307186}
# 979 e {'p': 0.0, 'e': 1.0}
# 980 e {'p': 0.0, 'e': 1.0}
# 981 e {'p': 7.91990978485146e-06, 'e': 0.9999920800902151}
# 982 e {'p': 0.0, 'e': 1.0}
# 983 e {'p': 1.2154236722764144e-05, 'e': 0.9999878457632773}
# 984 e {'p': 7.652525447014309e-07, 'e': 0.9999992347474552}
# 985 p {'p': 1.0, 'e': 0.0}
# 986 e {'p': 1.584849109932591e-07, 'e': 0.999999841515089}
# 987 e {'p': 0.0, 'e': 1.0}
# 988 e {'p': 0.0, 'e': 1.0}
# 989 e {'p': 0.0, 'e': 1.0}
# 990 e {'p': 0.0, 'e': 1.0}
# 991 e {'p': 0.0, 'e': 1.0}
# 992 e {'p': 0.0, 'e': 1.0}
# 993 e {'p': 6.547165127081543e-06, 'e': 0.999993452834873}
# 994 e {'p': 0.000963904548551567, 'e': 0.9990360954514484}
# 995 e {'p': 8.782966203100871e-07, 'e': 0.9999991217033798}
# 996 e {'p': 0.0, 'e': 1.0}
# 997 e {'p': 0.0, 'e': 1.0}
# 998 e {'p': 0.0, 'e': 1.0}
# 999 e {'p': 0.0, 'e': 1.0}
# 1000 p {'p': 1.0, 'e': 0.0}
# 1001 e {'p': 8.09457613932617e-06, 'e': 0.9999919054238607}
# 1002 e {'p': 0.0, 'e': 1.0}
# 1003 e {'p': 2.155766151912857e-06, 'e': 0.9999978442338481}
# 1004 p {'p': 1.0, 'e': 0.0}
# 1005 e {'p': 0.0, 'e': 1.0}
# 1006 e {'p': 0.0, 'e': 1.0}
# 1007 e {'p': 0.0, 'e': 1.0}
# 1008 e {'p': 1.5826247315150737e-06, 'e': 0.9999984173752685}
# 1009 e {'p': 0.0, 'e': 1.0}
# 1010 e {'p': 0.0, 'e': 1.0}
# 1011 e {'p': 0.0, 'e': 1.0}
# 1012 e {'p': 1.1299987411533252e-06, 'e': 0.9999988700012589}
# 1013 e {'p': 0.0, 'e': 1.0}
# 1014 e {'p': 1.0256458002456316e-06, 'e': 0.9999989743541998}
# 1015 e {'p': 7.106041358211452e-06, 'e': 0.9999928939586418}
# 1016 e {'p': 0.0, 'e': 1.0}
# 1017 e {'p': 0.0, 'e': 1.0}
# 1018 e {'p': 1.3666022629694833e-05, 'e': 0.9999863339773702}
# 1019 p {'p': 1.0, 'e': 0.0}
# 1020 e {'p': 9.049368978406322e-06, 'e': 0.9999909506310216}
# 1021 e {'p': 0.0, 'e': 1.0}
# 1022 e {'p': 0.0, 'e': 1.0}
# 1023 e {'p': 0.0, 'e': 1.0}
# 1024 e {'p': 0.0, 'e': 1.0}
# 1025 p {'p': 1.0, 'e': 0.0}
# 1026 p {'p': 1.0, 'e': 0.0}
# 1027 e {'p': 0.0008192752446691794, 'e': 0.9991807247553308}
# 1028 e {'p': 0.0, 'e': 1.0}
# 1029 e {'p': 0.0, 'e': 1.0}
# 1030 e {'p': 0.0, 'e': 1.0}
# 1031 e {'p': 0.0, 'e': 1.0}
# 1032 p {'p': 1.0, 'e': 0.0}
# 1033 e {'p': 2.0954966407772876e-06, 'e': 0.9999979045033592}
# 1034 e {'p': 2.4015191948944386e-06, 'e': 0.999997598480805}
# 1035 e {'p': 4.31127923761953e-06, 'e': 0.9999956887207624}
# 1036 e {'p': 0.0, 'e': 1.0}
# 1037 e {'p': 0.0, 'e': 1.0}
# 1038 e {'p': 0.0, 'e': 1.0}
# 1039 e {'p': 0.0003335475443423131, 'e': 0.9996664524556577}
# 1040 p {'p': 1.0, 'e': 0.0}
# 1041 e {'p': 0.0, 'e': 1.0}
# 1042 e {'p': 0.0, 'e': 1.0}
# 1043 e {'p': 0.0, 'e': 1.0}
# 1044 e {'p': 0.0, 'e': 1.0}
# 1045 e {'p': 0.0, 'e': 1.0}
# 1046 e {'p': 0.0, 'e': 1.0}
# 1047 e {'p': 7.22018157113772e-06, 'e': 0.9999927798184288}
# 1048 p {'p': 1.0, 'e': 0.0}
# 1049 e {'p': 0.0, 'e': 1.0}
# 1050 e {'p': 0.0, 'e': 1.0}
# 1051 e {'p': 9.348452000305805e-06, 'e': 0.9999906515479996}
# 1052 e {'p': 0.0, 'e': 1.0}
# 1053 e {'p': 0.0, 'e': 1.0}
# 1054 e {'p': 0.0, 'e': 1.0}
# 1055 e {'p': 6.773397931716929e-07, 'e': 0.9999993226602069}
# 1056 e {'p': 0.0, 'e': 1.0}
# 1057 e {'p': 0.0, 'e': 1.0}
# 1058 e {'p': 1.4620622584693882e-06, 'e': 0.9999985379377416}
# 1059 e {'p': 0.0, 'e': 1.0}
# 1060 e {'p': 1.0645908152792093e-05, 'e': 0.9999893540918472}
# 1061 e {'p': 0.0, 'e': 1.0}
# 1062 e {'p': 0.0, 'e': 1.0}
# 1063 e {'p': 1.5733131495582004e-06, 'e': 0.9999984266868504}
# 1064 e {'p': 2.7919140834022426e-07, 'e': 0.9999997208085916}
# 1065 p {'p': 1.0, 'e': 0.0}
# 1066 e {'p': 0.0, 'e': 1.0}
# 1067 e {'p': 0.0, 'e': 1.0}
# 1068 e {'p': 0.0, 'e': 1.0}
# 1069 e {'p': 0.0, 'e': 1.0}
# 1070 e {'p': 0.0, 'e': 1.0}
# 1071 e {'p': 0.0, 'e': 1.0}
# 1072 p {'p': 1.0, 'e': 0.0}
# 1073 e {'p': 0.0, 'e': 1.0}
# 1074 e {'p': 1.403168464669174e-05, 'e': 0.9999859683153532}
# 1075 e {'p': 0.0, 'e': 1.0}
# 1076 e {'p': 0.0, 'e': 1.0}
# 1077 e {'p': 0.0014567944937051128, 'e': 0.9985432055062949}
# 1078 p {'p': 1.0, 'e': 0.0}
# 1079 e {'p': 6.905158779630991e-07, 'e': 0.9999993094841221}
# 1080 e {'p': 0.0, 'e': 1.0}
# 1081 e {'p': 0.0, 'e': 1.0}
# 1082 p {'p': 1.0, 'e': 0.0}
# 1083 e {'p': 0.0, 'e': 1.0}
# 1084 e {'p': 3.2852550616298957e-07, 'e': 0.9999996714744938}
# 1085 e {'p': 0.0, 'e': 1.0}
# 1086 e {'p': 2.330046879537758e-06, 'e': 0.9999976699531204}
# 1087 e {'p': 0.0, 'e': 1.0}
# 1088 e {'p': 0.0, 'e': 1.0}
# 1089 p {'p': 1.0, 'e': 0.0}
# 1090 e {'p': 0.0, 'e': 1.0}
# 1091 e {'p': 0.0, 'e': 1.0}
# 1092 e {'p': 0.0, 'e': 1.0}
# 1093 e {'p': 0.0, 'e': 1.0}
# 1094 e {'p': 0.0, 'e': 1.0}
# 1095 e {'p': 0.0, 'e': 1.0}
# 1096 p {'p': 1.0, 'e': 0.0}
# 1097 e {'p': 0.0, 'e': 1.0}
# 1098 e {'p': 0.0, 'e': 1.0}
# 1099 e {'p': 9.142473365494248e-06, 'e': 0.9999908575266345}
# 1100 p {'p': 1.0, 'e': 0.0}
# 1101 e {'p': 0.0, 'e': 1.0}
# 1102 e {'p': 9.930681074846512e-07, 'e': 0.9999990069318926}
# 1103 e {'p': 1.0329074700035968e-05, 'e': 0.9999896709252999}
# 1104 p {'p': 1.0, 'e': 0.0}
# 1105 e {'p': 0.0, 'e': 1.0}
# 1106 e {'p': 0.0, 'e': 1.0}
# 1107 p {'p': 1.0, 'e': 0.0}
# 1108 e {'p': 0.0, 'e': 1.0}
# 1109 e {'p': 0.0, 'e': 1.0}
# 1110 e {'p': 0.0, 'e': 1.0}
# 1111 e {'p': 0.0, 'e': 1.0}
# 1112 p {'p': 1.0, 'e': 0.0}
# 1113 e {'p': 0.0, 'e': 1.0}
# 1114 e {'p': 0.0, 'e': 1.0}
# 1115 e {'p': 0.0, 'e': 1.0}
# 1116 e {'p': 3.5275084384245228e-06, 'e': 0.9999964724915615}
# 1117 e {'p': 3.1044153896069454e-07, 'e': 0.999999689558461}
# 1118 e {'p': 1.7011939665885877e-05, 'e': 0.999982988060334}
# 1119 e {'p': 7.531549759024039e-07, 'e': 0.9999992468450242}
# 1120 e {'p': 2.6168222127251303e-05, 'e': 0.9999738317778727}
# 1121 e {'p': 1.506223651059216e-06, 'e': 0.999998493776349}
# 1122 e {'p': 0.0, 'e': 1.0}
# 1123 e {'p': 4.576563589364084e-06, 'e': 0.9999954234364107}
# 1124 e {'p': 0.00020542741159902298, 'e': 0.999794572588401}
# 1125 e {'p': 0.0, 'e': 1.0}
# 1126 e {'p': 1.8008470873969872e-06, 'e': 0.9999981991529127}
# 1127 e {'p': 0.0, 'e': 1.0}
# 1128 e {'p': 0.0, 'e': 1.0}
# 1129 e {'p': 0.0, 'e': 1.0}
# 1130 e {'p': 0.0, 'e': 1.0}
# 1131 p {'p': 1.0, 'e': 0.0}
# 1132 e {'p': 0.0, 'e': 1.0}
# 1133 p {'p': 1.0, 'e': 0.0}
# 1134 e {'p': 6.941678813044765e-07, 'e': 0.9999993058321187}
# 1135 e {'p': 0.0, 'e': 1.0}
# 1136 e {'p': 1.1266051155633622e-05, 'e': 0.9999887339488444}
# 1137 e {'p': 2.1797247478286775e-06, 'e': 0.9999978202752521}
# 1138 e {'p': 0.0, 'e': 1.0}
# 1139 e {'p': 0.0, 'e': 1.0}
# 1140 e {'p': 0.0, 'e': 1.0}
# 1141 e {'p': 0.0, 'e': 1.0}
# 1142 e {'p': 5.367942378732956e-05, 'e': 0.9999463205762127}
# 1143 e {'p': 4.55735527479953e-06, 'e': 0.9999954426447252}
# 1144 e {'p': 0.0, 'e': 1.0}
# 1145 e {'p': 0.0, 'e': 1.0}
# 1146 e {'p': 2.2672663366637245e-07, 'e': 0.9999997732733663}
# 1147 e {'p': 1.8513226595610178e-06, 'e': 0.9999981486773404}
# 1148 e {'p': 0.0, 'e': 1.0}
# 1149 e {'p': 0.0, 'e': 1.0}
# 1150 e {'p': 0.0, 'e': 1.0}
# 1151 e {'p': 0.0, 'e': 1.0}
# 1152 e {'p': 0.0, 'e': 1.0}
# 1153 p {'p': 1.0, 'e': 0.0}
# 1154 e {'p': 0.0, 'e': 1.0}
# 1155 p {'p': 1.0, 'e': 0.0}
# 1156 e {'p': 0.0, 'e': 1.0}
# 1157 e {'p': 1.2803028684550135e-06, 'e': 0.9999987196971315}
# 1158 e {'p': 0.0, 'e': 1.0}
# 1159 e {'p': 2.1069449689817422e-07, 'e': 0.9999997893055032}
# 1160 e {'p': 1.800290860189506e-05, 'e': 0.999981997091398}
# 1161 e {'p': 0.0, 'e': 1.0}
# 1162 e {'p': 4.226743657045962e-07, 'e': 0.9999995773256343}
# 1163 e {'p': 2.578733452741427e-05, 'e': 0.9999742126654726}
# 1164 e {'p': 0.0, 'e': 1.0}
# 1165 e {'p': 6.606569548427815e-07, 'e': 0.9999993393430452}
# 1166 e {'p': 0.0, 'e': 1.0}
# 1167 p {'p': 1.0, 'e': 0.0}
# 1168 e {'p': 5.237144083703635e-05, 'e': 0.999947628559163}
# 1169 e {'p': 1.4672761674155583e-06, 'e': 0.9999985327238325}
# 1170 e {'p': 0.0, 'e': 1.0}
# 1171 e {'p': 1.070841777879028e-06, 'e': 0.9999989291582222}
# 1172 e {'p': 0.0, 'e': 1.0}
# 1173 e {'p': 0.0, 'e': 1.0}
# 1174 e {'p': 0.014523062456857964, 'e': 0.985476937543142}
# 1175 e {'p': 0.014096929400118495, 'e': 0.9859030705998815}
# 1176 e {'p': 0.0013453547113123096, 'e': 0.9986546452886876}
# 1177 e {'p': 0.0, 'e': 1.0}
# 1178 e {'p': 0.015248492578056525, 'e': 0.9847515074219435}
# 1179 e {'p': 0.0, 'e': 1.0}
# 1180 e {'p': 0.0, 'e': 1.0}
# 1181 e {'p': 0.0, 'e': 1.0}
# 1182 e {'p': 0.0, 'e': 1.0}
# 1183 e {'p': 0.0, 'e': 1.0}
# 1184 e {'p': 0.0, 'e': 1.0}
# 1185 e {'p': 0.0, 'e': 1.0}
# 1186 e {'p': 0.0, 'e': 1.0}
# 1187 e {'p': 0.0, 'e': 1.0}
# 1188 p {'p': 1.0, 'e': 0.0}
# 1189 e {'p': 0.0, 'e': 1.0}
# 1190 e {'p': 3.0897448763084606e-06, 'e': 0.9999969102551237}
# 1191 e {'p': 1.0528706281452275e-06, 'e': 0.9999989471293718}
# 1192 e {'p': 0.0, 'e': 1.0}
# 1193 e {'p': 0.0, 'e': 1.0}
# 1194 e {'p': 0.0, 'e': 1.0}
# 1195 e {'p': 0.0, 'e': 1.0}
# 1196 p {'p': 1.0, 'e': 0.0}
# 1197 e {'p': 6.571812516994966e-07, 'e': 0.9999993428187484}
# 1198 e {'p': 0.0, 'e': 1.0}
# 1199 e {'p': 0.0, 'e': 1.0}
# 1200 e {'p': 0.0, 'e': 1.0}
# 1201 e {'p': 0.0, 'e': 1.0}
# 1202 e {'p': 0.0, 'e': 1.0}
# 1203 e {'p': 0.0, 'e': 1.0}
# 1204 e {'p': 2.281344476215827e-06, 'e': 0.9999977186555238}
# 1205 p {'p': 1.0, 'e': 0.0}
# 1206 e {'p': 0.0, 'e': 1.0}
# 1207 e {'p': 0.0, 'e': 1.0}
# 1208 p {'p': 1.0, 'e': 0.0}
# 1209 e {'p': 0.0, 'e': 1.0}
# 1210 e {'p': 1.7017180586155386e-06, 'e': 0.9999982982819414}
# 1211 e {'p': 0.0, 'e': 1.0}
# 1212 e {'p': 0.0, 'e': 1.0}
# 1213 e {'p': 0.0, 'e': 1.0}
# 1214 e {'p': 0.0, 'e': 1.0}
# 1215 e {'p': 0.0, 'e': 1.0}
# 1216 p {'p': 1.0, 'e': 0.0}
# 1217 e {'p': 0.0, 'e': 1.0}
# 1218 e {'p': 3.040900457614193e-06, 'e': 0.9999969590995424}
# 1219 e {'p': 0.0, 'e': 1.0}
# 1220 e {'p': 2.7399650264702227e-07, 'e': 0.9999997260034974}
# 1221 e {'p': 0.0, 'e': 1.0}
# 1222 e {'p': 1.0997671138209217e-06, 'e': 0.9999989002328862}
# 1223 e {'p': 0.0, 'e': 1.0}
# 1224 e {'p': 7.32401239273625e-06, 'e': 0.9999926759876072}
# 1225 e {'p': 0.0, 'e': 1.0}
# 1226 e {'p': 4.4602435965113736e-07, 'e': 0.9999995539756404}
# 1227 e {'p': 0.0, 'e': 1.0}
# 1228 e {'p': 0.0, 'e': 1.0}
# 1229 p {'p': 1.0, 'e': 0.0}
# 1230 e {'p': 0.0, 'e': 1.0}
# 1231 e {'p': 3.440415999472094e-07, 'e': 0.9999996559584}
# 1232 p {'p': 1.0, 'e': 0.0}
# 1233 e {'p': 0.0, 'e': 1.0}
# 1234 e {'p': 0.0, 'e': 1.0}
# 1235 e {'p': 0.0, 'e': 1.0}
# 1236 e {'p': 0.0, 'e': 1.0}
# 1237 e {'p': 0.0, 'e': 1.0}
# 1238 e {'p': 8.028336367667059e-06, 'e': 0.9999919716636323}
# 1239 e {'p': 1.8292075659363367e-05, 'e': 0.9999817079243406}
# 1240 e {'p': 1.99513816333145e-05, 'e': 0.9999800486183666}
# 1241 p {'p': 1.0, 'e': 0.0}
# 1242 e {'p': 0.0, 'e': 1.0}
# 1243 p {'p': 1.0, 'e': 0.0}
# 1244 p {'p': 1.0, 'e': 0.0}
# 1245 e {'p': 1.506909883300588e-06, 'e': 0.9999984930901167}
# 1246 e {'p': 0.0, 'e': 1.0}
# 1247 e {'p': 0.0, 'e': 1.0}
# 1248 e {'p': 0.0, 'e': 1.0}
# 1249 e {'p': 0.0, 'e': 1.0}
# 1250 e {'p': 0.0, 'e': 1.0}
# 1251 e {'p': 0.0, 'e': 1.0}
# 1252 e {'p': 2.361304551232396e-06, 'e': 0.9999976386954489}
# 1253 e {'p': 0.0, 'e': 1.0}
# 1254 p {'p': 1.0, 'e': 0.0}
# 1255 p {'p': 1.0, 'e': 0.0}
# 1256 e {'p': 0.0, 'e': 1.0}
# 1257 p {'p': 1.0, 'e': 0.0}
# 1258 e {'p': 8.756608865419709e-06, 'e': 0.9999912433911345}
# 1259 e {'p': 0.0, 'e': 1.0}
# 1260 p {'p': 1.0, 'e': 0.0}
# 1261 p {'p': 1.0, 'e': 0.0}
# 1262 p {'p': 1.0, 'e': 0.0}
# 1263 p {'p': 1.0, 'e': 0.0}
# 1264 e {'p': 0.0, 'e': 1.0}
# 1265 e {'p': 0.0, 'e': 1.0}
# 1266 e {'p': 0.0, 'e': 1.0}
# 1267 e {'p': 0.0, 'e': 1.0}
# 1268 p {'p': 1.0, 'e': 0.0}
# 1269 e {'p': 6.242905396647504e-07, 'e': 0.9999993757094603}
# 1270 e {'p': 8.993418354600354e-06, 'e': 0.9999910065816454}
# 1271 e {'p': 1.1907018988423611e-06, 'e': 0.9999988092981011}
# 1272 e {'p': 4.015202869662343e-07, 'e': 0.999999598479713}
# 1273 p {'p': 1.0, 'e': 0.0}
# 1274 e {'p': 0.0, 'e': 1.0}
# 1275 e {'p': 6.204950210488574e-06, 'e': 0.9999937950497895}
# 1276 p {'p': 1.0, 'e': 0.0}
# 1277 e {'p': 0.0, 'e': 1.0}
# 1278 e {'p': 3.014170411584119e-07, 'e': 0.9999996985829589}
# 1279 e {'p': 1.572004724501098e-05, 'e': 0.999984279952755}
# 1280 e {'p': 1.3815152706738365e-05, 'e': 0.9999861848472933}
# 1281 e {'p': 0.0, 'e': 1.0}
# 1282 e {'p': 0.0, 'e': 1.0}
# 1283 e {'p': 2.0052322388136768e-07, 'e': 0.9999997994767761}
# 1284 e {'p': 1.042935570101088e-06, 'e': 0.9999989570644299}
# 1285 e {'p': 0.0, 'e': 1.0}
# 1286 e {'p': 0.0, 'e': 1.0}
# 1287 p {'p': 1.0, 'e': 0.0}
# 1288 e {'p': 2.5754549601781953e-05, 'e': 0.9999742454503981}
# 1289 e {'p': 0.0, 'e': 1.0}
# 1290 e {'p': 0.0, 'e': 1.0}
# 1291 e {'p': 0.0, 'e': 1.0}
# 1292 e {'p': 0.0, 'e': 1.0}
# 1293 e {'p': 0.0, 'e': 1.0}
# 1294 p {'p': 1.0, 'e': 0.0}
# 1295 p {'p': 1.0, 'e': 0.0}
# 1296 e {'p': 0.0, 'e': 1.0}
# 1297 e {'p': 0.0, 'e': 1.0}
# 1298 e {'p': 1.3914813135153973e-06, 'e': 0.9999986085186864}
# 1299 e {'p': 0.0, 'e': 1.0}
# 1300 e {'p': 0.0, 'e': 1.0}
# 1301 e {'p': 0.0, 'e': 1.0}
# 1302 e {'p': 0.0, 'e': 1.0}
# 1303 e {'p': 1.154594618958687e-05, 'e': 0.9999884540538104}
# 1304 e {'p': 6.018973297617167e-07, 'e': 0.9999993981026702}
# 1305 e {'p': 0.0, 'e': 1.0}
# 1306 e {'p': 2.9097169059363303e-05, 'e': 0.9999709028309406}
# 1307 e {'p': 2.873511922593066e-06, 'e': 0.9999971264880775}
# 1308 e {'p': 8.29950057482504e-07, 'e': 0.9999991700499425}
# 1309 e {'p': 0.0, 'e': 1.0}
# 1310 e {'p': 8.44493538151981e-06, 'e': 0.9999915550646186}
# 1311 e {'p': 1.7622426359042874e-07, 'e': 0.9999998237757365}
# 1312 e {'p': 0.0, 'e': 1.0}
# 1313 p {'p': 1.0, 'e': 0.0}
# 1314 e {'p': 0.0, 'e': 1.0}
# 1315 e {'p': 0.0, 'e': 1.0}
# 1316 e {'p': 4.97485627405067e-07, 'e': 0.9999995025143725}
# 1317 e {'p': 2.091607749468872e-06, 'e': 0.9999979083922506}
# 1318 e {'p': 0.0, 'e': 1.0}
# 1319 e {'p': 0.0, 'e': 1.0}
# 1320 e {'p': 4.562420571663245e-06, 'e': 0.9999954375794284}
# 1321 e {'p': 2.42370266800496e-06, 'e': 0.999997576297332}
# 1322 p {'p': 1.0, 'e': 0.0}
# 1323 e {'p': 2.6679002487655597e-07, 'e': 0.9999997332099752}
# 1324 p {'p': 1.0, 'e': 0.0}
# 1325 e {'p': 0.0, 'e': 1.0}
# 1326 e {'p': 0.0, 'e': 1.0}
# 1327 e {'p': 0.0, 'e': 1.0}
# 1328 e {'p': 0.0, 'e': 1.0}
# 1329 e {'p': 0.0, 'e': 1.0}
# 1330 e {'p': 5.107970394021036e-07, 'e': 0.9999994892029606}
# 1331 e {'p': 7.857286922372248e-07, 'e': 0.9999992142713078}
# 1332 e {'p': 0.0, 'e': 1.0}
# 1333 p {'p': 1.0, 'e': 0.0}
# 1334 e {'p': 0.0, 'e': 1.0}
# 1335 e {'p': 0.0, 'e': 1.0}
# 1336 e {'p': 0.0, 'e': 1.0}
# 1337 e {'p': 0.0, 'e': 1.0}
# 1338 e {'p': 3.4259705532032897e-06, 'e': 0.9999965740294467}
# 1339 e {'p': 0.0, 'e': 1.0}
# 1340 e {'p': 4.148096782751665e-07, 'e': 0.9999995851903217}
# 1341 e {'p': 0.0, 'e': 1.0}
# 1342 e {'p': 0.0, 'e': 1.0}
# 1343 p {'p': 1.0, 'e': 0.0}
# 1344 e {'p': 0.0, 'e': 1.0}
# 1345 e {'p': 7.636375575254213e-07, 'e': 0.9999992363624424}
# 1346 e {'p': 0.0, 'e': 1.0}
# 1347 p {'p': 1.0, 'e': 0.0}
# 1348 e {'p': 2.6674358731574288e-06, 'e': 0.9999973325641268}
# 1349 e {'p': 0.0, 'e': 1.0}
# 1350 e {'p': 1.780050402866176e-05, 'e': 0.9999821994959713}
# 1351 e {'p': 0.0, 'e': 1.0}
# 1352 e {'p': 1.2603753050312063e-06, 'e': 0.999998739624695}
# 1353 e {'p': 9.657013675928475e-06, 'e': 0.9999903429863242}
# 1354 e {'p': 0.0, 'e': 1.0}
# 1355 e {'p': 0.0, 'e': 1.0}
# 1356 e {'p': 0.0, 'e': 1.0}
# 1357 e {'p': 3.045178437993609e-07, 'e': 0.9999996954821562}
# 1358 e {'p': 0.0, 'e': 1.0}
# 1359 e {'p': 0.0, 'e': 1.0}
# 1360 e {'p': 6.759103367349756e-07, 'e': 0.9999993240896632}
# 1361 e {'p': 0.0, 'e': 1.0}
# 1362 p {'p': 1.0, 'e': 0.0}
# 1363 e {'p': 0.0, 'e': 1.0}
# 1364 e {'p': 3.3509636152218833e-06, 'e': 0.9999966490363847}
# 1365 e {'p': 0.0, 'e': 1.0}
# 1366 e {'p': 1.1062760383123894e-06, 'e': 0.9999988937239617}
# 1367 e {'p': 0.0, 'e': 1.0}
# 1368 e {'p': 0.0, 'e': 1.0}
# 1369 e {'p': 0.0, 'e': 1.0}
# 1370 e {'p': 0.0, 'e': 1.0}
# 1371 e {'p': 2.125631377249258e-06, 'e': 0.9999978743686228}
# 1372 e {'p': 8.283794498571145e-06, 'e': 0.9999917162055014}
# 1373 e {'p': 4.33734994168428e-06, 'e': 0.9999956626500583}
# 1374 e {'p': 0.0, 'e': 1.0}
# 1375 p {'p': 1.0, 'e': 0.0}
# 1376 p {'p': 1.0, 'e': 0.0}
# 1377 e {'p': 3.4667439326079877e-07, 'e': 0.9999996533256067}
# 1378 e {'p': 9.004752671018382e-07, 'e': 0.999999099524733}
# 1379 p {'p': 1.0, 'e': 0.0}
# 1380 e {'p': 2.5414131613978536e-06, 'e': 0.9999974585868385}
# 1381 p {'p': 1.0, 'e': 0.0}
# 1382 e {'p': 0.0, 'e': 1.0}
# 1383 p {'p': 1.0, 'e': 0.0}
# 1384 e {'p': 0.0, 'e': 1.0}
# 1385 e {'p': 0.0, 'e': 1.0}
# 1386 e {'p': 0.0, 'e': 1.0}
# 1387 e {'p': 8.509078633836535e-07, 'e': 0.9999991490921366}
# 1388 e {'p': 1.7841805934748348e-05, 'e': 0.9999821581940652}
# 1389 e {'p': 0.0, 'e': 1.0}
# 1390 e {'p': 5.349217210677568e-07, 'e': 0.9999994650782789}
# 1391 e {'p': 0.0, 'e': 1.0}
# 1392 e {'p': 1.4854736397606227e-05, 'e': 0.9999851452636024}
# 1393 e {'p': 0.0, 'e': 1.0}
# 1394 e {'p': 3.815997995613027e-06, 'e': 0.9999961840020044}
# 1395 e {'p': 6.107111245521861e-07, 'e': 0.9999993892888754}
# 1396 e {'p': 1.368342651781934e-05, 'e': 0.9999863165734821}
# 1397 e {'p': 7.464044222110059e-07, 'e': 0.9999992535955778}
# 1398 e {'p': 2.3872528427447773e-05, 'e': 0.9999761274715726}
# 1399 e {'p': 5.90313595392932e-06, 'e': 0.9999940968640461}
# 1400 p {'p': 1.0, 'e': 0.0}
# 1401 e {'p': 1.5946909015672934e-06, 'e': 0.9999984053090984}
# 1402 e {'p': 0.0, 'e': 1.0}
# 1403 e {'p': 0.0, 'e': 1.0}
# 1404 e {'p': 0.0, 'e': 1.0}
# 1405 e {'p': 0.0, 'e': 1.0}
# 1406 p {'p': 1.0, 'e': 0.0}
# 1407 e {'p': 0.0, 'e': 1.0}
# 1408 e {'p': 0.0, 'e': 1.0}
# 1409 e {'p': 0.0, 'e': 1.0}
# 1410 e {'p': 1.3865087839463325e-06, 'e': 0.999998613491216}
# 1411 e {'p': 4.734695243191179e-07, 'e': 0.9999995265304756}
# 1412 e {'p': 6.438626911727191e-06, 'e': 0.9999935613730884}
# 1413 e {'p': 0.0, 'e': 1.0}
# 1414 e {'p': 0.0, 'e': 1.0}
# 1415 e {'p': 0.0, 'e': 1.0}
# 1416 e {'p': 0.0, 'e': 1.0}
# 1417 e {'p': 0.0, 'e': 1.0}
# 1418 e {'p': 0.0, 'e': 1.0}
# 1419 e {'p': 1.529948406707688e-05, 'e': 0.9999847005159329}
# 1420 e {'p': 0.0, 'e': 1.0}
# 1421 p {'p': 1.0, 'e': 0.0}
# 1422 e {'p': 3.189196390937803e-06, 'e': 0.999996810803609}
# 1423 e {'p': 0.0, 'e': 1.0}
# 1424 e {'p': 5.309845494461518e-07, 'e': 0.9999994690154506}
# 1425 e {'p': 0.0, 'e': 1.0}
# 1426 e {'p': 0.0, 'e': 1.0}
# 1427 e {'p': 8.70397535449867e-06, 'e': 0.9999912960246454}
# 1428 e {'p': 1.6190701718981383e-05, 'e': 0.999983809298281}
# 1429 e {'p': 0.0, 'e': 1.0}
# 1430 p {'p': 1.0, 'e': 0.0}
# 1431 e {'p': 5.471754645914105e-06, 'e': 0.9999945282453542}
# 1432 e {'p': 1.568677601476479e-05, 'e': 0.9999843132239853}
# 1433 p {'p': 1.0, 'e': 0.0}
# 1434 p {'p': 1.0, 'e': 0.0}
# 1435 p {'p': 1.0, 'e': 0.0}
# 1436 e {'p': 0.0, 'e': 1.0}
# 1437 e {'p': 0.0, 'e': 1.0}
# 1438 p {'p': 1.0, 'e': 0.0}
# 1439 e {'p': 0.0, 'e': 1.0}
# 1440 e {'p': 5.744100994561017e-07, 'e': 0.9999994255899005}
# 1441 e {'p': 0.0, 'e': 1.0}
# 1442 e {'p': 0.0, 'e': 1.0}
# 1443 e {'p': 3.6357117911485042e-06, 'e': 0.9999963642882089}
# ...
# 3661 e {'p': 8.60960180815105e-06, 'e': 0.9999913903981918}
# 3662 p {'p': 1.0, 'e': 0.0}
# 3663 e {'p': 9.495513395770107e-06, 'e': 0.9999905044866043}
# 3664 p {'p': 1.0, 'e': 0.0}
# 3665 e {'p': 0.0, 'e': 1.0}
# 3666 e {'p': 0.000375439078048888, 'e': 0.9996245609219511}
# 3667 e {'p': 0.0001267773611354546, 'e': 0.9998732226388646}
# 3668 p {'p': 1.0, 'e': 0.0}
# 3669 e {'p': 9.79989664821037e-06, 'e': 0.9999902001033517}
# 3670 e {'p': 0.0, 'e': 1.0}
# 3671 p {'p': 1.0, 'e': 0.0}
# 3672 e {'p': 4.367176155725241e-06, 'e': 0.9999956328238443}
# 3673 e {'p': 0.0, 'e': 1.0}
# 3674 e {'p': 1.3964116711645088e-06, 'e': 0.9999986035883288}
# 3675 e {'p': 0.0, 'e': 1.0}
# 3676 p {'p': 1.0, 'e': 0.0}
# 3677 e {'p': 0.0, 'e': 1.0}
# 3678 e {'p': 0.0, 'e': 1.0}
# 3679 e {'p': 1.990291653317975e-05, 'e': 0.9999800970834668}
# 3680 p {'p': 1.0, 'e': 0.0}
# 3681 e {'p': 3.832296010833949e-05, 'e': 0.9999616770398916}
# 3682 e {'p': 0.0, 'e': 1.0}
# 3683 e {'p': 1.0596047627202254e-05, 'e': 0.9999894039523729}
# 3684 p {'p': 1.0, 'e': 0.0}
# 3685 p {'p': 1.0, 'e': 0.0}
# 3686 e {'p': 4.8555353058191764e-05, 'e': 0.9999514446469417}
# 3687 p {'p': 1.0, 'e': 0.0}
# 3688 p {'p': 1.0, 'e': 0.0}
# 3689 e {'p': 0.0, 'e': 1.0}
# 3690 e {'p': 3.7975501490586947e-05, 'e': 0.9999620244985095}
# 3691 e {'p': 6.04949577869418e-06, 'e': 0.9999939505042214}
# 3692 e {'p': 4.711034770111452e-05, 'e': 0.9999528896522988}
# 3693 p {'p': 1.0, 'e': 0.0}
# 3694 e {'p': 4.1267821300367614e-06, 'e': 0.99999587321787}
# 3695 p {'p': 1.0, 'e': 0.0}
# 3696 e {'p': 0.0, 'e': 1.0}
# 3697 e {'p': 0.0, 'e': 1.0}
# 3698 p {'p': 1.0, 'e': 0.0}
# 3699 e {'p': 0.0, 'e': 1.0}
# 3700 p {'p': 1.0, 'e': 0.0}
# 3701 e {'p': 5.176220540196406e-06, 'e': 0.9999948237794597}
# 3702 p {'p': 1.0, 'e': 0.0}
# 3703 e {'p': 0.0, 'e': 1.0}
# 3704 p {'p': 1.0, 'e': 0.0}
# 3705 p {'p': 1.0, 'e': 0.0}
# 3706 e {'p': 0.0, 'e': 1.0}
# 3707 e {'p': 0.0, 'e': 1.0}
# 3708 p {'p': 1.0, 'e': 0.0}
# 3709 p {'p': 1.0, 'e': 0.0}
# 3710 e {'p': 1.542022760239222e-06, 'e': 0.9999984579772397}
# 3711 p {'p': 1.0, 'e': 0.0}
# 3712 e {'p': 0.00013613491942497956, 'e': 0.999863865080575}
# 3713 e {'p': 2.1588335266960066e-05, 'e': 0.9999784116647331}
# 3714 p {'p': 1.0, 'e': 0.0}
# 3715 e {'p': 2.9259527536598866e-06, 'e': 0.9999970740472464}
# 3716 e {'p': 7.205528536293936e-05, 'e': 0.9999279447146371}
# 3717 e {'p': 0.0, 'e': 1.0}
# 3718 e {'p': 0.0, 'e': 1.0}
# 3719 p {'p': 1.0, 'e': 0.0}
# 3720 e {'p': 0.0, 'e': 1.0}
# 3721 e {'p': 9.583281117889553e-06, 'e': 0.9999904167188821}
# 3722 e {'p': 0.000512419865030429, 'e': 0.9994875801349696}
# 3723 e {'p': 3.148657192619689e-05, 'e': 0.9999685134280738}
# 3724 e {'p': 0.0, 'e': 1.0}
# 3725 p {'p': 1.0, 'e': 0.0}
# 3726 p {'p': 1.0, 'e': 0.0}
# 3727 p {'p': 1.0, 'e': 0.0}
# 3728 e {'p': 0.0, 'e': 1.0}
# 3729 e {'p': 0.0, 'e': 1.0}
# 3730 e {'p': 0.0, 'e': 1.0}
# 3731 e {'p': 3.279403062651878e-05, 'e': 0.9999672059693735}
# 3732 e {'p': 0.0, 'e': 1.0}
# 3733 e {'p': 0.0, 'e': 1.0}
# 3734 e {'p': 0.0, 'e': 1.0}
# 3735 p {'p': 1.0, 'e': 0.0}
# 3736 e {'p': 7.78731311542454e-05, 'e': 0.9999221268688459}
# 3737 e {'p': 9.97715594097956e-06, 'e': 0.999990022844059}
# 3738 p {'p': 1.0, 'e': 0.0}
# 3739 p {'p': 1.0, 'e': 0.0}
# 3740 p {'p': 1.0, 'e': 0.0}
# 3741 e {'p': 0.0, 'e': 1.0}
# 3742 p {'p': 1.0, 'e': 0.0}
# 3743 p {'p': 1.0, 'e': 0.0}
# 3744 e {'p': 0.0, 'e': 1.0}
# 3745 e {'p': 2.4980108195893202e-06, 'e': 0.9999975019891805}
# 3746 e {'p': 0.0, 'e': 1.0}
# 3747 p {'p': 1.0, 'e': 0.0}
# 3748 e {'p': 0.0, 'e': 1.0}
# 3749 e {'p': 9.822635198547125e-06, 'e': 0.9999901773648014}
# 3750 e {'p': 3.5443577072033746e-05, 'e': 0.999964556422928}
# 3751 p {'p': 1.0, 'e': 0.0}
# 3752 p {'p': 1.0, 'e': 0.0}
# 3753 e {'p': 1.5815235450188338e-05, 'e': 0.9999841847645498}
# 3754 p {'p': 1.0, 'e': 0.0}
# 3755 p {'p': 1.0, 'e': 0.0}
# 3756 p {'p': 1.0, 'e': 0.0}
# 3757 e {'p': 2.1907469440015275e-05, 'e': 0.9999780925305599}
# 3758 e {'p': 0.0, 'e': 1.0}
# 3759 p {'p': 1.0, 'e': 0.0}
# 3760 e {'p': 0.0, 'e': 1.0}
# 3761 e {'p': 8.446716881374861e-05, 'e': 0.9999155328311862}
# 3762 e {'p': 8.32432547802272e-06, 'e': 0.999991675674522}
# 3763 e {'p': 0.0, 'e': 1.0}
# 3764 e {'p': 8.820452117615932e-06, 'e': 0.9999911795478824}
# 3765 e {'p': 5.502952806194166e-06, 'e': 0.9999944970471938}
# 3766 e {'p': 8.92734640821509e-05, 'e': 0.999910726535918}
# 3767 e {'p': 0.0, 'e': 1.0}
# 3768 e {'p': 1.5249913367363478e-05, 'e': 0.9999847500866327}
# 3769 e {'p': 2.1532027204367553e-05, 'e': 0.9999784679727957}
# 3770 e {'p': 0.0, 'e': 1.0}
# 3771 e {'p': 1.325930857717311e-05, 'e': 0.9999867406914228}
# 3772 e {'p': 3.613061261170777e-05, 'e': 0.9999638693873882}
# 3773 e {'p': 0.0, 'e': 1.0}
# 3774 e {'p': 0.0, 'e': 1.0}
# 3775 e {'p': 1.6101297679509498e-05, 'e': 0.9999838987023205}
# 3776 p {'p': 1.0, 'e': 0.0}
# 3777 e {'p': 6.28535971611956e-05, 'e': 0.9999371464028388}
# 3778 e {'p': 0.0, 'e': 1.0}
# 3779 e {'p': 0.0001755937789579366, 'e': 0.9998244062210421}
# 3780 e {'p': 0.0, 'e': 1.0}
# 3781 e {'p': 0.0, 'e': 1.0}
# 3782 p {'p': 1.0, 'e': 0.0}
# 3783 e {'p': 3.552581414809565e-05, 'e': 0.9999644741858519}
# 3784 p {'p': 1.0, 'e': 0.0}
# 3785 e {'p': 1.8247641205535913e-05, 'e': 0.9999817523587944}
# 3786 e {'p': 0.0, 'e': 1.0}
# 3787 e {'p': 2.2454873574017106e-06, 'e': 0.9999977545126425}
# 3788 p {'p': 1.0, 'e': 0.0}
# 3789 e {'p': 0.0, 'e': 1.0}
# 3790 e {'p': 0.0, 'e': 1.0}
# 3791 p {'p': 1.0, 'e': 0.0}
# 3792 e {'p': 0.0, 'e': 1.0}
# 3793 p {'p': 1.0, 'e': 0.0}
# 3794 e {'p': 2.1504640931303645e-05, 'e': 0.9999784953590687}
# 3795 p {'p': 1.0, 'e': 0.0}
# 3796 e {'p': 2.389472623059244e-05, 'e': 0.9999761052737695}
# 3797 p {'p': 1.0, 'e': 0.0}
# 3798 e {'p': 0.00022729291562357908, 'e': 0.9997727070843765}
# 3799 e {'p': 0.0, 'e': 1.0}
# 3800 e {'p': 2.7974955531479197e-05, 'e': 0.9999720250444686}
# 3801 e {'p': 0.0, 'e': 1.0}
# 3802 p {'p': 1.0, 'e': 0.0}
# 3803 e {'p': 1.0582570520728938e-05, 'e': 0.9999894174294792}
# 3804 e {'p': 0.0, 'e': 1.0}
# 3805 p {'p': 1.0, 'e': 0.0}
# 3806 e {'p': 1.4580520700295667e-05, 'e': 0.9999854194792998}
# 3807 p {'p': 1.0, 'e': 0.0}
# 3808 e {'p': 0.0, 'e': 1.0}
# 3809 p {'p': 1.0, 'e': 0.0}
# 3810 e {'p': 0.0, 'e': 1.0}
# 3811 p {'p': 1.0, 'e': 0.0}
# 3812 e {'p': 8.641757824686571e-05, 'e': 0.9999135824217532}
# 3813 e {'p': 0.0001283444578386313, 'e': 0.9998716555421614}
# 3814 e {'p': 7.807676443972619e-05, 'e': 0.9999219232355603}
# 3815 p {'p': 1.0, 'e': 0.0}
# 3816 p {'p': 1.0, 'e': 0.0}
# 3817 e {'p': 0.0, 'e': 1.0}
# 3818 e {'p': 5.797372198903875e-06, 'e': 0.9999942026278011}
# 3819 e {'p': 6.4018913350327955e-06, 'e': 0.9999935981086651}
# 3820 e {'p': 0.0, 'e': 1.0}
# 3821 e {'p': 1.0370758493793805e-05, 'e': 0.9999896292415061}
# 3822 e {'p': 2.1148533079401862e-06, 'e': 0.9999978851466921}
# 3823 p {'p': 1.0, 'e': 0.0}
# 3824 e {'p': 0.0, 'e': 1.0}
# 3825 e {'p': 9.573272898597366e-06, 'e': 0.9999904267271014}
# 3826 e {'p': 4.456371762873889e-06, 'e': 0.9999955436282372}
# 3827 p {'p': 1.0, 'e': 0.0}
# 3828 e {'p': 0.0, 'e': 1.0}
# 3829 e {'p': 9.680225066582019e-06, 'e': 0.9999903197749335}
# 3830 p {'p': 1.0, 'e': 0.0}
# 3831 e {'p': 5.577200001543582e-06, 'e': 0.9999944227999985}
# 3832 p {'p': 1.0, 'e': 0.0}
# 3833 e {'p': 6.330909841093522e-05, 'e': 0.999936690901589}
# 3834 p {'p': 1.0, 'e': 0.0}
# 3835 p {'p': 1.0, 'e': 0.0}
# 3836 p {'p': 1.0, 'e': 0.0}
# 3837 e {'p': 0.0, 'e': 1.0}
# 3838 e {'p': 0.0, 'e': 1.0}
# 3839 e {'p': 6.277365788192486e-05, 'e': 0.9999372263421181}
# 3840 e {'p': 0.0, 'e': 1.0}
# 3841 p {'p': 1.0, 'e': 0.0}
# 3842 e {'p': 3.804595736414366e-06, 'e': 0.9999961954042637}
# 3843 e {'p': 0.0, 'e': 1.0}
# 3844 p {'p': 1.0, 'e': 0.0}
# 3845 e {'p': 0.0, 'e': 1.0}
# 3846 p {'p': 1.0, 'e': 0.0}
# 3847 e {'p': 0.0, 'e': 1.0}
# 3848 e {'p': 0.0, 'e': 1.0}
# 3849 e {'p': 1.0000049528371161e-05, 'e': 0.9999899999504716}
# 3850 e {'p': 1.2708379408602688e-05, 'e': 0.9999872916205914}
# 3851 e {'p': 1.047101163007303e-06, 'e': 0.999998952898837}
# 3852 e {'p': 5.332387377316255e-06, 'e': 0.9999946676126227}
# 3853 p {'p': 1.0, 'e': 0.0}
# 3854 e {'p': 2.0400010778995587e-05, 'e': 0.999979599989221}
# 3855 p {'p': 1.0, 'e': 0.0}
# 3856 e {'p': 4.1568160090130936e-05, 'e': 0.9999584318399098}
# 3857 e {'p': 0.0, 'e': 1.0}
# 3858 e {'p': 0.0, 'e': 1.0}
# 3859 p {'p': 1.0, 'e': 0.0}
# 3860 p {'p': 1.0, 'e': 0.0}
# 3861 e {'p': 5.6074190472457895e-06, 'e': 0.9999943925809528}
# 3862 e {'p': 0.0, 'e': 1.0}
# 3863 e {'p': 0.0, 'e': 1.0}
# 3864 e {'p': 0.0, 'e': 1.0}
# 3865 p {'p': 1.0, 'e': 0.0}
# 3866 p {'p': 1.0, 'e': 0.0}
# 3867 e {'p': 3.6168927522910914e-06, 'e': 0.9999963831072477}
# 3868 e {'p': 0.0, 'e': 1.0}
# 3869 p {'p': 1.0, 'e': 0.0}
# 3870 p {'p': 1.0, 'e': 0.0}
# 3871 e {'p': 0.000848121290090956, 'e': 0.9991518787099091}
# 3872 p {'p': 1.0, 'e': 0.0}
# 3873 p {'p': 1.0, 'e': 0.0}
# 3874 p {'p': 1.0, 'e': 0.0}
# 3875 p {'p': 1.0, 'e': 0.0}
# 3876 e {'p': 0.0, 'e': 1.0}
# 3877 p {'p': 1.0, 'e': 0.0}
# 3878 e {'p': 0.0, 'e': 1.0}
# 3879 p {'p': 1.0, 'e': 0.0}
# 3880 p {'p': 1.0, 'e': 0.0}
# 3881 e {'p': 0.0, 'e': 1.0}
# 3882 p {'p': 1.0, 'e': 0.0}
# 3883 p {'p': 1.0, 'e': 0.0}
# 3884 e {'p': 0.0, 'e': 1.0}
# 3885 e {'p': 0.0, 'e': 1.0}
# 3886 p {'p': 1.0, 'e': 0.0}
# 3887 e {'p': 0.0, 'e': 1.0}
# 3888 p {'p': 1.0, 'e': 0.0}
# 3889 e {'p': 0.0, 'e': 1.0}
# 3890 p {'p': 1.0, 'e': 0.0}
# 3891 p {'p': 1.0, 'e': 0.0}
# 3892 e {'p': 0.0, 'e': 1.0}
# 3893 p {'p': 1.0, 'e': 0.0}
# 3894 e {'p': 0.0, 'e': 1.0}
# 3895 p {'p': 1.0, 'e': 0.0}
# 3896 p {'p': 1.0, 'e': 0.0}
# 3897 e {'p': 4.833752549515451e-06, 'e': 0.9999951662474504}
# 3898 e {'p': 0.0, 'e': 1.0}
# 3899 p {'p': 1.0, 'e': 0.0}
# 3900 e {'p': 6.493498634268669e-07, 'e': 0.9999993506501366}
# 3901 p {'p': 1.0, 'e': 0.0}
# 3902 p {'p': 1.0, 'e': 0.0}
# 3903 p {'p': 1.0, 'e': 0.0}
# 3904 p {'p': 1.0, 'e': 0.0}
# 3905 p {'p': 1.0, 'e': 0.0}
# 3906 p {'p': 1.0, 'e': 0.0}
# 3907 p {'p': 1.0, 'e': 0.0}
# 3908 p {'p': 1.0, 'e': 0.0}
# 3909 p {'p': 1.0, 'e': 0.0}
# 3910 p {'p': 1.0, 'e': 0.0}
# 3911 e {'p': 0.0, 'e': 1.0}
# 3912 p {'p': 1.0, 'e': 0.0}
# 3913 p {'p': 1.0, 'e': 0.0}
# 3914 p {'p': 1.0, 'e': 0.0}
# 3915 e {'p': 1.3289999991356278e-06, 'e': 0.9999986710000008}
# 3916 e {'p': 0.0, 'e': 1.0}
# 3917 e {'p': 3.928009436780727e-05, 'e': 0.9999607199056322}
# 3918 p {'p': 1.0, 'e': 0.0}
# 3919 p {'p': 1.0, 'e': 0.0}
# 3920 p {'p': 1.0, 'e': 0.0}
# 3921 e {'p': 2.275730995325653e-05, 'e': 0.9999772426900467}
# 3922 p {'p': 1.0, 'e': 0.0}
# 3923 e {'p': 0.0, 'e': 1.0}
# 3924 e {'p': 0.0, 'e': 1.0}
# 3925 e {'p': 0.0, 'e': 1.0}
# 3926 p {'p': 1.0, 'e': 0.0}
# 3927 p {'p': 1.0, 'e': 0.0}
# 3928 p {'p': 1.0, 'e': 0.0}
# 3929 e {'p': 0.0, 'e': 1.0}
# 3930 p {'p': 1.0, 'e': 0.0}
# 3931 p {'p': 1.0, 'e': 0.0}
# 3932 p {'p': 1.0, 'e': 0.0}
# 3933 p {'p': 1.0, 'e': 0.0}
# 3934 p {'p': 1.0, 'e': 0.0}
# 3935 p {'p': 1.0, 'e': 0.0}
# 3936 p {'p': 1.0, 'e': 0.0}
# 3937 p {'p': 1.0, 'e': 0.0}
# 3938 e {'p': 0.0, 'e': 1.0}
# 3939 e {'p': 0.0, 'e': 1.0}
# 3940 p {'p': 1.0, 'e': 0.0}
# 3941 p {'p': 1.0, 'e': 0.0}
# 3942 p {'p': 1.0, 'e': 0.0}
# 3943 e {'p': 3.336311360767847e-05, 'e': 0.9999666368863924}
# 3944 e {'p': 0.0, 'e': 1.0}
# 3945 p {'p': 1.0, 'e': 0.0}
# 3946 e {'p': 0.0, 'e': 1.0}
# 3947 p {'p': 1.0, 'e': 0.0}
# 3948 p {'p': 1.0, 'e': 0.0}
# 3949 e {'p': 0.0, 'e': 1.0}
# 3950 p {'p': 1.0, 'e': 0.0}
# 3951 p {'p': 1.0, 'e': 0.0}
# 3952 p {'p': 1.0, 'e': 0.0}
# 3953 p {'p': 1.0, 'e': 0.0}
# 3954 p {'p': 1.0, 'e': 0.0}
# 3955 p {'p': 1.0, 'e': 0.0}
# 3956 p {'p': 1.0, 'e': 0.0}
# 3957 p {'p': 1.0, 'e': 0.0}
# 3958 p {'p': 1.0, 'e': 0.0}
# 3959 e {'p': 5.465570806228288e-06, 'e': 0.9999945344291937}
# 3960 p {'p': 1.0, 'e': 0.0}
# 3961 p {'p': 1.0, 'e': 0.0}
# 3962 e {'p': 7.592902715574465e-05, 'e': 0.9999240709728442}
# 3963 p {'p': 1.0, 'e': 0.0}
# 3964 p {'p': 1.0, 'e': 0.0}
# 3965 p {'p': 1.0, 'e': 0.0}
# 3966 p {'p': 1.0, 'e': 0.0}
# 3967 p {'p': 1.0, 'e': 0.0}
# 3968 p {'p': 1.0, 'e': 0.0}
# 3969 p {'p': 1.0, 'e': 0.0}
# 3970 p {'p': 1.0, 'e': 0.0}
# 3971 p {'p': 1.0, 'e': 0.0}
# 3972 p {'p': 1.0, 'e': 0.0}
# 3973 e {'p': 7.37792779814279e-05, 'e': 0.9999262207220185}
# 3974 e {'p': 2.0967747708236083e-05, 'e': 0.9999790322522918}
# 3975 p {'p': 1.0, 'e': 0.0}
# 3976 p {'p': 1.0, 'e': 0.0}
# 3977 p {'p': 1.0, 'e': 0.0}
# 3978 p {'p': 1.0, 'e': 0.0}
# 3979 p {'p': 1.0, 'e': 0.0}
# 3980 e {'p': 3.5571055823650446e-05, 'e': 0.9999644289441764}
# 3981 p {'p': 1.0, 'e': 0.0}
# 3982 p {'p': 1.0, 'e': 0.0}
# 3983 p {'p': 1.0, 'e': 0.0}
# 3984 p {'p': 1.0, 'e': 0.0}
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 6
#       3 for i in range(len(features)):
#       4     row = features.iloc[i]
# ----> 6     out = predict(list(row))
#       8     # Check if the prediction is correct
#       9     if out == targets.iloc[i].item():
#
# Cell In[3], line 15, in predict(feature)
#      12 for i,column in enumerate(features):
#      13     category = feature[i]
# ---> 15     P_category = sum(features[column].str.count(category)) / total
#      17     filtered = targets[features[column] == category]["class"]
#      18     P_label_category = len(filtered[filtered == target]) / len(filtered)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\strings\accessor.py:2413, in StringMethods.count(self, pat, flags)
#    2348 @forbid_nonstring_types(["bytes"])
#    2349 def count(self, pat, flags: int = 0):
#    2350     r"""
#    2351     Count occurrences of pattern in each string of the Series/Index.
#    2352
#    (...)
#    2411     Index([0, 0, 2, 1], dtype='int64')
#    2412     """
# -> 2413     result = self._data.array._str_count(pat, flags)
#    2414     return self._wrap_result(result, returns_string=False)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\strings\object_array.py:109, in ObjectStringArrayMixin._str_count(self, pat, flags)
#     108 def _str_count(self, pat, flags: int = 0):
# --> 109     regex = re.compile(pat, flags=flags)
#     110     f = lambda x: len(regex.findall(x))
#     111     return self._str_map(f, dtype="int64")
#
# File c:\Program Files\Python39\lib\re.py:252, in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#
# File c:\Program Files\Python39\lib\re.py:304, in _compile(pattern, flags)
#     302 if not sre_compile.isstring(pattern):
#     303     raise TypeError("first argument must be string or compiled pattern")
# --> 304 p = sre_compile.compile(pattern, flags)
#     305 if not (flags & DEBUG):
#     306     if len(_cache) >= _MAXCACHE:
#     307         # Drop the oldest item
#
# File c:\Program Files\Python39\lib\sre_compile.py:764, in compile(p, flags)
#     762 if isstring(p):
#     763     pattern = p
# --> 764     p = sre_parse.parse(p, flags)
#     765 else:
#     766     pattern = None
#
# File c:\Program Files\Python39\lib\sre_parse.py:948, in parse(str, flags, state)
#     945 state.str = str
#     947 try:
# --> 948     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     949 except Verbose:
#     950     # the VERBOSE flag was switched on inside the pattern.  to be
#     951     # on the safe side, we'll parse the whole thing again...
#     952     state = State()
#
# File c:\Program Files\Python39\lib\sre_parse.py:443, in _parse_sub(source, state, verbose, nested)
#     441 start = source.tell()
#     442 while True:
# --> 443     itemsappend(_parse(source, state, verbose, nested + 1,
#     444                        not nested and not items))
#     445     if not sourcematch("|"):
#     446         break
#
# File c:\Program Files\Python39\lib\sre_parse.py:668, in _parse(source, state, verbose, nested, first)
#     666     item = None
#     667 if not item or item[0][0] is AT:
# --> 668     raise source.error("nothing to repeat",
#     669                        source.tell() - here + len(this))
#     670 if item[0][0] in _REPEATCODES:
#     671     raise source.error("multiple repeat",
#     672                        source.tell() - here + len(this))
#
# error: nothing to repeat at position 0
