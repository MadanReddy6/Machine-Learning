# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn import linear_model
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 from sklearn import linear_model
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\__init__.py:65
#      58     _module = _err.name
#      59     raise ImportError(
#      60         f"C extension: {_module} not built. If you want to import "
#      61         "pandas from the source directory, you may need to run "
#      62         "'python setup.py build_ext' to build the C extensions first."
#      63     ) from _err
# ---> 65 from pandas._config import (
#      66     get_option,
#      67     set_option,
#      68     reset_option,
#      69     describe_option,
#      70     option_context,
#      71     options,
#      72 )
#      74 # let init-time option registration happen
#      75 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_config\__init__.py:20
#       1 """
#       2 pandas._config is considered explicitly upstream of everything else in pandas,
#       3 should have no intra-pandas dependencies.
#    (...)
#       6 are initialized.
#       7 """
#       8 __all__ = [
#       9     "config",
#      10     "detect_console_encoding",
#    (...)
#      18     "warn_copy_on_write",
#      19 ]
# ---> 20 from pandas._config import config
#      21 from pandas._config import dates  # pyright: ignore[reportUnusedImport]  # noqa: F401
#      22 from pandas._config.config import (
#      23     _global_config,
#      24     describe_option,
#    (...)
#      29     set_option,
#      30 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_config\config.py:68
#      58 from typing import (
#      59     TYPE_CHECKING,
#      60     Any,
#    (...)
#      64     cast,
#      65 )
#      66 import warnings
# ---> 68 from pandas._typing import (
#      69     F,
#      70     T,
#      71 )
#      72 from pandas.util._exceptions import find_stack_level
#      74 if TYPE_CHECKING:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_typing.py:198
#     192 Frequency = Union[str, "BaseOffset"]
#     193 Axes = ListLike
#     195 RandomState = Union[
#     196     int,
#     197     np.ndarray,
# --> 198     np.random.Generator,
#     199     np.random.BitGenerator,
#     200     np.random.RandomState,
#     201 ]
#     203 # dtypes
#     204 NpDtype = Union[str, np.dtype, type_t[Union[str, complex, bool, object]]]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\__init__.py:366, in __getattr__(attr)
#     365 def __dir__():
# --> 366     public_symbols = globals().keys() | {'testing'}
#     367     public_symbols -= {
#     368         "core", "matrixlib",
#     369         # These were moved in 1.25 and may be deprecated eventually:
#     370         "ModuleDeprecationWarning", "VisibleDeprecationWarning",
#     371         "ComplexWarning", "TooHardError", "AxisError"
#     372     }
#     373     return list(public_symbols)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\random\__init__.py:180
#     126 __all__ = [
#     127     'beta',
#     128     'binomial',
#    (...)
#     176     'zipf',
#     177 ]
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\random\_pickle.py:1
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#
# File numpy\\random\\mtrand.pyx:1, in init numpy.random.mtrand()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.0.1

# %%
df = pd.read_csv("house_price.csv")

df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  560000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  505000
# 4  4000       6.0    8  760000

# %%
import math
median_bedrooms = math.floor(df.bedrooms.median())
median_bedrooms
# Out:
# 3

# %%
df.bedrooms = df.bedrooms.fillna(median_bedrooms)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  560000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       3.0   30  505000
# 4  4000       6.0    8  760000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([    92.75656274, -16740.50632911, -11374.35222156])

# %%
reg.intercept_
# Out:
# np.float64(566385.6086993455)

# %%
reg.predict([[3000,4,15]])
# Out:
# c:\Users\K Madan Mohan Reddy\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([607077.98827627])
